# %%
import pandas as pd
from sklearn.metrics import accuracy_score
import re
from collections import OrderedDict

# %%
X_train = pd.read_excel('full-data/X_train.xlsx')

# %%
X_test = pd.read_excel('full-data/X_test.xlsx')

# %%
y_train = pd.read_excel('full-data/y_train.xlsx')

# %%
y_test = pd.read_excel('full-data/y_test.xlsx')

# %%
# Baseline #1 -> Just use W-V and W-H to see who wins, if tie then give to H
baseline_preds = []
for r, row in X_test.iterrows():
    W_V = row['W-V']
    L_V = row['L-V']
    W_H = row['W-H']
    L_H = row['L-H']
    choice = 1 if W_H >= W_V else 0
    baseline_preds.append(choice)
accuracy_score(baseline_preds, y_test)
# Out:
# 0.7021362353889561

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import GridSearchCV
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
X_train_data = X_train.values
X_test_data = X_test.values
y_train_data = y_train.values.flatten()
y_test_data = y_test.values.flatten()

# %%
# XGBoost
from xgboost import XGBClassifier

xgb = XGBClassifier(n_jobs=-1)
param_grid_xgb = {
    'n_estimators': [100, 200, 500, 1000],
    'learning_rate': [.001, .01, .05, .1, 1]
}
grid_search_xgb = GridSearchCV(xgb, param_grid_xgb, cv=kf, n_jobs=-1)
grid_search_xgb.fit(X_train_data, y_train_data, early_stopping_rounds=5, eval_set=[(X_test_data, y_test_data)], verbose=False)

# xgb.fit(X_train_data, y_train_data, early_stopping_rounds=5, eval_set=[(X_test_data, y_test_data)], verbose=False)

print(grid_search_xgb.best_params_)
print(grid_search_xgb.best_score_)
# pd.DataFrame(grid_search_xgb.cv_results_)
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}
# 0.6689516129032258

# %%
feature_names = {num: val for num, val in enumerate(X_train.columns.tolist())}

# %%
feature_gain = grid_search_xgb.best_estimator_.get_booster().get_score(importance_type='gain')

# %%
# Make a dataframe for the feature importances
feature_importances = []
for i, name in enumerate(feature_names.values()):
    label = 'f{}'.format(i)
    gain = gain = feature_gain[label] if label in feature_gain else None
    feature_importances.append([name, gain])
importance_df = pd.DataFrame(feature_importances, columns=['Feature', 'Gain'])

# %%
importance_df.sort_values(by='Gain', ascending=False)
# Out:
#         Feature       Gain
# 240    NetRtg-H  57.761836
# 249       PIE-V  45.577457
# 241    NetRtg-V  32.989168
# 248       PIE-H  24.732565
# 220  WS/48-S1-H  22.123787
# ..          ...        ...
# 250      REB%-H        NaN
# 251      REB%-V        NaN
# 253      TOV%-V        NaN
# 254       TS%-H        NaN
# 257      eFG%-V        NaN
#
# [258 rows x 2 columns]

# %%
importance_df.to_excel('feature_importance.xlsx', index=False)
# Out:
# C:\Users\Max Brenner\Anaconda3\lib\site-packages\pandas\compat\_optional.py:106: UserWarning: Pandas requires version '0.9.8' or newer of 'xlsxwriter' (version '0.9.6' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
cross_val_score(grid_search_xgb.best_estimator_, X_test_data, y_test_data, cv=kf).mean()
# Out:
# C:\Users\Max Brenner\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Max Brenner\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Max Brenner\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Max Brenner\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Max Brenner\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.6767459596287402

# %%
y_pred = grid_search_xgb.best_estimator_.predict(X_test_data)
accuracy_score(y_test, y_pred)
# Out:
# C:\Users\Max Brenner\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.6968964127367997

# %%
# See how much the preds differ from baseline
accuracy_score(baseline_preds, y_pred)
# Out:
# 0.8182184602982668

# %%
# From above it seems that the model is more similar to the baseline (just using wins to answer) then the target

# %%
X_train_pre_drop = pd.read_excel('full-data/X_train_pre_drop.xlsx')
X_test_pre_drop = pd.read_excel('full-data/X_test_pre_drop.xlsx')

# %%
# Get when the model was wrong
incorrects = []
for t, p in zip(y_test.values.flatten(), y_pred):
    if t != p: incorrects.append(1)
    else: incorrects.append(0)

# %%
# Get when the baseline was wrong
incorrects_baseline = []
for t, p in zip(y_test.values.flatten(), baseline_preds):
    if t != p: incorrects_baseline.append(1)
    else: incorrects_baseline.append(0)

# %%
X_test_pre_drop.head(2)
# Out:
#               Date           Visitor  PTS-V                Home  PTS-H  W-V  \
# 0  Sun Nov 24 2019  Sacramento Kings    113  Washington Wizards    106    7
# 1   Sat Jan 9 2016     Chicago Bulls    105       Atlanta Hawks    120   22
#
#    L-V  W-H  L-H  Rest-V  ...  PIE-H  PIE-V  REB%-H  REB%-V  TOV%-H  TOV%-V  \
# 0    8    5    9       2  ...   47.8   47.0    47.8    48.9    13.4    14.8
# 1   13   23   15       2  ...   52.8   49.4    47.4    50.6    15.2    14.2
#
#    TS%-H  TS%-V  eFG%-H  eFG%-V
# 0   56.6   55.8    52.9    52.7
# 1   55.2   52.6    51.6    48.7
#
# [2 rows x 263 columns]

# %%
# Tally when in the season games too place that the model predicted incorrectly
# And tally years
months_ticks = OrderedDict({'Oct': 0, 'Nov': 0, 'Dec': 0, 'Jan': 0, 'Feb': 0, 'Mar': 0, 'Apr': 0})
months_totals = OrderedDict({'Oct': 0, 'Nov': 0, 'Dec': 0, 'Jan': 0, 'Feb': 0, 'Mar': 0, 'Apr': 0})

years_ticks = OrderedDict({2015: 0, 2016: 0, 2017: 0, 2018: 0, 2019: 0})
years_totals = OrderedDict({2015: 0, 2016: 0, 2017: 0, 2018: 0, 2019: 0})

def which_season(year, month):
    if month in ['Oct', 'Nov', 'Dec']:
        return int(year)
    else:
        return int(year) - 1

for (r, row), inc in zip(X_test_pre_drop.iterrows(), incorrects):
    date_regex = re.match(r'\w+\s(\w+)\s(\d+)\s(\d+)', row['Date'])
    month = date_regex.group(1)
    year = date_regex.group(3)
    which_seas = which_season(year, month)
    years_totals[which_seas] += 1
    months_totals[month] += 1
    if not inc:
        continue
    months_ticks[month] += 1
    years_ticks[which_seas] += 1

for (month, tick), total in zip(list(months_ticks.items()), list(months_totals.values())):
    print('{}: {}/{} ticks  {} proportion'.format(month, tick, total, tick/total if not total==0 else 'N/A'))
print('\n\n')
for (year, tick), total in zip(list(years_ticks.items()), list(years_totals.values())):
    print('{}: {}/{} ticks  {} proportion'.format(year, tick, total, tick/total if not total==0 else 'N/A'))
# Out:
# Oct: 0/0 ticks  N/A proportion
# Nov: 103/358 ticks  0.2877094972067039 proportion
# Dec: 171/555 ticks  0.3081081081081081 proportion
# Jan: 180/568 ticks  0.31690140845070425 proportion
# Feb: 117/381 ticks  0.30708661417322836 proportion
# Mar: 123/431 ticks  0.2853828306264501 proportion
# Apr: 58/188 ticks  0.30851063829787234 proportion
#
#
#
# 2015: 149/548 ticks  0.2718978102189781 proportion
# 2016: 187/548 ticks  0.34124087591240876 proportion
# 2017: 170/530 ticks  0.32075471698113206 proportion
# 2018: 150/528 ticks  0.2840909090909091 proportion
# 2019: 96/327 ticks  0.29357798165137616 proportion

# %%
# BASELINE

# Tally when in the season games too place that the model predicted incorrectly
# And tally years
months_ticks = OrderedDict({'Oct': 0, 'Nov': 0, 'Dec': 0, 'Jan': 0, 'Feb': 0, 'Mar': 0, 'Apr': 0})
months_totals = OrderedDict({'Oct': 0, 'Nov': 0, 'Dec': 0, 'Jan': 0, 'Feb': 0, 'Mar': 0, 'Apr': 0})

years_ticks = OrderedDict({2015: 0, 2016: 0, 2017: 0, 2018: 0, 2019: 0})
years_totals = OrderedDict({2015: 0, 2016: 0, 2017: 0, 2018: 0, 2019: 0})

def which_season(year, month):
    if month in ['Oct', 'Nov', 'Dec']:
        return int(year)
    else:
        return int(year) - 1

for (r, row), inc in zip(X_test_pre_drop.iterrows(), incorrects_baseline):
    date_regex = re.match(r'\w+\s(\w+)\s(\d+)\s(\d+)', row['Date'])
    month = date_regex.group(1)
    year = date_regex.group(3)
    which_seas = which_season(year, month)
    years_totals[which_seas] += 1
    months_totals[month] += 1
    if not inc:
        continue
    months_ticks[month] += 1
    years_ticks[which_seas] += 1

for (month, tick), total in zip(list(months_ticks.items()), list(months_totals.values())):
    print('{}: {}/{} ticks  {} proportion'.format(month, tick, total, tick/total if not total==0 else 'N/A'))
print('\n\n')
for (year, tick), total in zip(list(years_ticks.items()), list(years_totals.values())):
    print('{}: {}/{} ticks  {} proportion'.format(year, tick, total, tick/total if not total==0 else 'N/A'))
# Out:
# Oct: 0/0 ticks  N/A proportion
# Nov: 94/358 ticks  0.26256983240223464 proportion
# Dec: 168/555 ticks  0.3027027027027027 proportion
# Jan: 165/568 ticks  0.2904929577464789 proportion
# Feb: 127/381 ticks  0.3333333333333333 proportion
# Mar: 126/431 ticks  0.2923433874709977 proportion
# Apr: 59/188 ticks  0.31382978723404253 proportion
#
#
#
# 2015: 155/548 ticks  0.28284671532846717 proportion
# 2016: 194/548 ticks  0.354014598540146 proportion
# 2017: 152/530 ticks  0.28679245283018867 proportion
# 2018: 153/528 ticks  0.2897727272727273 proportion
# 2019: 85/327 ticks  0.2599388379204893 proportion

# %%
# Tally per season for each team the incorrects
ticks = OrderedDict()
totals = OrderedDict()

# init the dicts of dicts
teams = X_train_pre_drop.Visitor.unique().tolist()
years = [2015, 2016, 2017, 2018, 2019]
for year in years:
    ticks[year] = OrderedDict()
    totals[year] = OrderedDict()
    for team in teams:
        ticks[year][team] = 0
        totals[year][team] = 0

# tally
for (r, row), inc in zip(X_test_pre_drop.iterrows(), incorrects):
    date_regex = re.match(r'\w+\s(\w+)\s(\d+)\s(\d+)', row['Date'])
    month = date_regex.group(1)
    year = date_regex.group(3)
    which_seas = which_season(year, month)
    v = row['Visitor']
    h = row['Home']
    totals[which_seas][v] += 1
    totals[which_seas][h] += 1
    if not inc:
        continue
    ticks[which_seas][v] += 1
    ticks[which_seas][h] += 1

# print
for year, teams_dict in list(ticks.items()):
    print(' --- {} ---'.format(year))
    for (team, tick), total in zip(list(teams_dict.items()), list(totals[year].values())):
        print('{}: {}/{} ticks  {} proportion'.format(team, tick, total, tick/total))
    print('\n')
# Out:
#  --- 2015 ---
# Orlando Magic: 13/46 ticks  0.2826086956521739 proportion
# San Antonio Spurs: 4/31 ticks  0.12903225806451613 proportion
# Brooklyn Nets: 9/33 ticks  0.2727272727272727 proportion
# Philadelphia 76ers: 6/42 ticks  0.14285714285714285 proportion
# Memphis Grizzlies: 12/38 ticks  0.3157894736842105 proportion
# Detroit Pistons: 12/34 ticks  0.35294117647058826 proportion
# Cleveland Cavaliers: 9/38 ticks  0.23684210526315788 proportion
# Indiana Pacers: 10/32 ticks  0.3125 proportion
# Golden State Warriors: 4/31 ticks  0.12903225806451613 proportion
# Dallas Mavericks: 12/36 ticks  0.3333333333333333 proportion
# Denver Nuggets: 14/32 ticks  0.4375 proportion
# Portland Trail Blazers: 11/33 ticks  0.3333333333333333 proportion
# New York Knicks: 7/30 ticks  0.23333333333333334 proportion
# Washington Wizards: 6/39 ticks  0.15384615384615385 proportion
# Sacramento Kings: 15/36 ticks  0.4166666666666667 proportion
# Atlanta Hawks: 8/31 ticks  0.25806451612903225 proportion
# Charlotte Hornets: 7/31 ticks  0.22580645161290322 proportion
# Houston Rockets: 10/34 ticks  0.29411764705882354 proportion
# Utah Jazz: 13/39 ticks  0.3333333333333333 proportion
# Los Angeles Lakers: 6/40 ticks  0.15 proportion
# Boston Celtics: 12/41 ticks  0.2926829268292683 proportion
# Los Angeles Clippers: 11/28 ticks  0.39285714285714285 proportion
# Phoenix Suns: 12/44 ticks  0.2727272727272727 proportion
# Minnesota Timberwolves: 16/41 ticks  0.3902439024390244 proportion
# Toronto Raptors: 8/43 ticks  0.18604651162790697 proportion
# New Orleans Pelicans: 15/47 ticks  0.3191489361702128 proportion
# Miami Heat: 8/35 ticks  0.22857142857142856 proportion
# Milwaukee Bucks: 8/44 ticks  0.18181818181818182 proportion
# Chicago Bulls: 14/34 ticks  0.4117647058823529 proportion
# Oklahoma City Thunder: 6/33 ticks  0.18181818181818182 proportion
#
#
#  --- 2016 ---
# Orlando Magic: 14/33 ticks  0.42424242424242425 proportion
# San Antonio Spurs: 9/38 ticks  0.23684210526315788 proportion
# Brooklyn Nets: 8/36 ticks  0.2222222222222222 proportion
# Philadelphia 76ers: 15/46 ticks  0.32608695652173914 proportion
# Memphis Grizzlies: 16/39 ticks  0.41025641025641024 proportion
# Detroit Pistons: 13/37 ticks  0.35135135135135137 proportion
# Cleveland Cavaliers: 11/40 ticks  0.275 proportion
# Indiana Pacers: 11/37 ticks  0.2972972972972973 proportion
# Golden State Warriors: 5/31 ticks  0.16129032258064516 proportion
# Dallas Mavericks: 13/41 ticks  0.3170731707317073 proportion
# Denver Nuggets: 12/31 ticks  0.3870967741935484 proportion
# Portland Trail Blazers: 18/39 ticks  0.46153846153846156 proportion
# New York Knicks: 7/30 ticks  0.23333333333333334 proportion
# Washington Wizards: 11/41 ticks  0.2682926829268293 proportion
# Sacramento Kings: 10/33 ticks  0.30303030303030304 proportion
# Atlanta Hawks: 18/35 ticks  0.5142857142857142 proportion
# Charlotte Hornets: 14/37 ticks  0.3783783783783784 proportion
# Houston Rockets: 15/39 ticks  0.38461538461538464 proportion
# Utah Jazz: 9/28 ticks  0.32142857142857145 proportion
# Los Angeles Lakers: 9/33 ticks  0.2727272727272727 proportion
# Boston Celtics: 10/39 ticks  0.2564102564102564 proportion
# Los Angeles Clippers: 13/34 ticks  0.38235294117647056 proportion
# Phoenix Suns: 10/30 ticks  0.3333333333333333 proportion
# Minnesota Timberwolves: 15/35 ticks  0.42857142857142855 proportion
# Toronto Raptors: 16/45 ticks  0.35555555555555557 proportion
# New Orleans Pelicans: 13/35 ticks  0.37142857142857144 proportion
# Miami Heat: 14/37 ticks  0.3783783783783784 proportion
# Milwaukee Bucks: 13/33 ticks  0.3939393939393939 proportion
# Chicago Bulls: 21/40 ticks  0.525 proportion
# Oklahoma City Thunder: 11/44 ticks  0.25 proportion
#
#
#  --- 2017 ---
# Orlando Magic: 7/34 ticks  0.20588235294117646 proportion
# San Antonio Spurs: 4/33 ticks  0.12121212121212122 proportion
# Brooklyn Nets: 16/35 ticks  0.45714285714285713 proportion
# Philadelphia 76ers: 9/35 ticks  0.2571428571428571 proportion
# Memphis Grizzlies: 7/32 ticks  0.21875 proportion
# Detroit Pistons: 11/30 ticks  0.36666666666666664 proportion
# Cleveland Cavaliers: 9/33 ticks  0.2727272727272727 proportion
# Indiana Pacers: 14/34 ticks  0.4117647058823529 proportion
# Golden State Warriors: 10/39 ticks  0.2564102564102564 proportion
# Dallas Mavericks: 14/32 ticks  0.4375 proportion
# Denver Nuggets: 12/35 ticks  0.34285714285714286 proportion
# Portland Trail Blazers: 9/36 ticks  0.25 proportion
# New York Knicks: 17/43 ticks  0.3953488372093023 proportion
# Washington Wizards: 15/33 ticks  0.45454545454545453 proportion
# Sacramento Kings: 13/37 ticks  0.35135135135135137 proportion
# Atlanta Hawks: 6/31 ticks  0.1935483870967742 proportion
# Charlotte Hornets: 14/42 ticks  0.3333333333333333 proportion
# Houston Rockets: 5/37 ticks  0.13513513513513514 proportion
# Utah Jazz: 16/40 ticks  0.4 proportion
# Los Angeles Lakers: 10/33 ticks  0.30303030303030304 proportion
# Boston Celtics: 15/42 ticks  0.35714285714285715 proportion
# Los Angeles Clippers: 11/36 ticks  0.3055555555555556 proportion
# Phoenix Suns: 11/45 ticks  0.24444444444444444 proportion
# Minnesota Timberwolves: 8/33 ticks  0.24242424242424243 proportion
# Toronto Raptors: 8/32 ticks  0.25 proportion
# New Orleans Pelicans: 11/31 ticks  0.3548387096774194 proportion
# Miami Heat: 13/34 ticks  0.38235294117647056 proportion
# Milwaukee Bucks: 17/37 ticks  0.4594594594594595 proportion
# Chicago Bulls: 11/32 ticks  0.34375 proportion
# Oklahoma City Thunder: 17/34 ticks  0.5 proportion
#
#
#  --- 2018 ---
# Orlando Magic: 11/30 ticks  0.36666666666666664 proportion
# San Antonio Spurs: 8/40 ticks  0.2 proportion
# Brooklyn Nets: 10/32 ticks  0.3125 proportion
# Philadelphia 76ers: 17/37 ticks  0.4594594594594595 proportion
# Memphis Grizzlies: 8/31 ticks  0.25806451612903225 proportion
# Detroit Pistons: 11/38 ticks  0.2894736842105263 proportion
# Cleveland Cavaliers: 6/43 ticks  0.13953488372093023 proportion
# Indiana Pacers: 7/27 ticks  0.25925925925925924 proportion
# Golden State Warriors: 10/37 ticks  0.2702702702702703 proportion
# Dallas Mavericks: 6/29 ticks  0.20689655172413793 proportion
# Denver Nuggets: 7/39 ticks  0.1794871794871795 proportion
# Portland Trail Blazers: 11/38 ticks  0.2894736842105263 proportion
# New York Knicks: 6/34 ticks  0.17647058823529413 proportion
# Washington Wizards: 11/34 ticks  0.3235294117647059 proportion
# Sacramento Kings: 10/40 ticks  0.25 proportion
# Atlanta Hawks: 12/38 ticks  0.3157894736842105 proportion
# Charlotte Hornets: 12/38 ticks  0.3157894736842105 proportion
# Houston Rockets: 16/36 ticks  0.4444444444444444 proportion
# Utah Jazz: 4/31 ticks  0.12903225806451613 proportion
# Los Angeles Lakers: 9/33 ticks  0.2727272727272727 proportion
# Boston Celtics: 12/30 ticks  0.4 proportion
# Los Angeles Clippers: 9/41 ticks  0.21951219512195122 proportion
# Phoenix Suns: 9/34 ticks  0.2647058823529412 proportion
# Minnesota Timberwolves: 11/32 ticks  0.34375 proportion
# Toronto Raptors: 13/39 ticks  0.3333333333333333 proportion
# New Orleans Pelicans: 9/30 ticks  0.3 proportion
# Miami Heat: 11/34 ticks  0.3235294117647059 proportion
# Milwaukee Bucks: 11/40 ticks  0.275 proportion
# Chicago Bulls: 6/34 ticks  0.17647058823529413 proportion
# Oklahoma City Thunder: 17/37 ticks  0.4594594594594595 proportion
#
#
#  --- 2019 ---
# Orlando Magic: 3/22 ticks  0.13636363636363635 proportion
# San Antonio Spurs: 9/17 ticks  0.5294117647058824 proportion
# Brooklyn Nets: 5/21 ticks  0.23809523809523808 proportion
# Philadelphia 76ers: 3/19 ticks  0.15789473684210525 proportion
# Memphis Grizzlies: 4/19 ticks  0.21052631578947367 proportion
# Detroit Pistons: 9/24 ticks  0.375 proportion
# Cleveland Cavaliers: 9/25 ticks  0.36 proportion
# Indiana Pacers: 8/24 ticks  0.3333333333333333 proportion
# Golden State Warriors: 3/19 ticks  0.15789473684210525 proportion
# Dallas Mavericks: 11/24 ticks  0.4583333333333333 proportion
# Denver Nuggets: 11/23 ticks  0.4782608695652174 proportion
# Portland Trail Blazers: 8/19 ticks  0.42105263157894735 proportion
# New York Knicks: 10/26 ticks  0.38461538461538464 proportion
# Washington Wizards: 11/27 ticks  0.4074074074074074 proportion
# Sacramento Kings: 5/22 ticks  0.22727272727272727 proportion
# Atlanta Hawks: 7/23 ticks  0.30434782608695654 proportion
# Charlotte Hornets: 5/21 ticks  0.23809523809523808 proportion
# Houston Rockets: 7/20 ticks  0.35 proportion
# Utah Jazz: 5/22 ticks  0.22727272727272727 proportion
# Los Angeles Lakers: 8/26 ticks  0.3076923076923077 proportion
# Boston Celtics: 4/19 ticks  0.21052631578947367 proportion
# Los Angeles Clippers: 7/22 ticks  0.3181818181818182 proportion
# Phoenix Suns: 10/27 ticks  0.37037037037037035 proportion
# Minnesota Timberwolves: 5/20 ticks  0.25 proportion
# Toronto Raptors: 4/20 ticks  0.2 proportion
# New Orleans Pelicans: 3/19 ticks  0.15789473684210525 proportion
# Miami Heat: 5/19 ticks  0.2631578947368421 proportion
# Milwaukee Bucks: 3/21 ticks  0.14285714285714285 proportion
# Chicago Bulls: 3/20 ticks  0.15 proportion
# Oklahoma City Thunder: 7/24 ticks  0.2916666666666667 proportion

# %%
# BASELINE

# Tally per season for each team the incorrects
ticks = OrderedDict()
totals = OrderedDict()

# init the dicts of dicts
teams = X_train_pre_drop.Visitor.unique().tolist()
years = [2015, 2016, 2017, 2018, 2019]
for year in years:
    ticks[year] = OrderedDict()
    totals[year] = OrderedDict()
    for team in teams:
        ticks[year][team] = 0
        totals[year][team] = 0

# tally
for (r, row), inc in zip(X_test_pre_drop.iterrows(), incorrects_baseline):
    date_regex = re.match(r'\w+\s(\w+)\s(\d+)\s(\d+)', row['Date'])
    month = date_regex.group(1)
    year = date_regex.group(3)
    which_seas = which_season(year, month)
    v = row['Visitor']
    h = row['Home']
    totals[which_seas][v] += 1
    totals[which_seas][h] += 1
    if not inc:
        continue
    ticks[which_seas][v] += 1
    ticks[which_seas][h] += 1

# print
for year, teams_dict in list(ticks.items()):
    print(' --- {} ---'.format(year))
    for (team, tick), total in zip(list(teams_dict.items()), list(totals[year].values())):
        print('{}: {}/{} ticks  {} proportion'.format(team, tick, total, tick/total))
    print('\n')
# Out:
#  --- 2015 ---
# Orlando Magic: 14/46 ticks  0.30434782608695654 proportion
# San Antonio Spurs: 5/31 ticks  0.16129032258064516 proportion
# Brooklyn Nets: 8/33 ticks  0.24242424242424243 proportion
# Philadelphia 76ers: 7/42 ticks  0.16666666666666666 proportion
# Memphis Grizzlies: 9/38 ticks  0.23684210526315788 proportion
# Detroit Pistons: 12/34 ticks  0.35294117647058826 proportion
# Cleveland Cavaliers: 9/38 ticks  0.23684210526315788 proportion
# Indiana Pacers: 9/32 ticks  0.28125 proportion
# Golden State Warriors: 4/31 ticks  0.12903225806451613 proportion
# Dallas Mavericks: 11/36 ticks  0.3055555555555556 proportion
# Denver Nuggets: 10/32 ticks  0.3125 proportion
# Portland Trail Blazers: 11/33 ticks  0.3333333333333333 proportion
# New York Knicks: 8/30 ticks  0.26666666666666666 proportion
# Washington Wizards: 14/39 ticks  0.358974358974359 proportion
# Sacramento Kings: 15/36 ticks  0.4166666666666667 proportion
# Atlanta Hawks: 7/31 ticks  0.22580645161290322 proportion
# Charlotte Hornets: 8/31 ticks  0.25806451612903225 proportion
# Houston Rockets: 10/34 ticks  0.29411764705882354 proportion
# Utah Jazz: 14/39 ticks  0.358974358974359 proportion
# Los Angeles Lakers: 8/40 ticks  0.2 proportion
# Boston Celtics: 15/41 ticks  0.36585365853658536 proportion
# Los Angeles Clippers: 8/28 ticks  0.2857142857142857 proportion
# Phoenix Suns: 13/44 ticks  0.29545454545454547 proportion
# Minnesota Timberwolves: 12/41 ticks  0.2926829268292683 proportion
# Toronto Raptors: 9/43 ticks  0.20930232558139536 proportion
# New Orleans Pelicans: 20/47 ticks  0.425531914893617 proportion
# Miami Heat: 8/35 ticks  0.22857142857142856 proportion
# Milwaukee Bucks: 10/44 ticks  0.22727272727272727 proportion
# Chicago Bulls: 15/34 ticks  0.4411764705882353 proportion
# Oklahoma City Thunder: 7/33 ticks  0.21212121212121213 proportion
#
#
#  --- 2016 ---
# Orlando Magic: 13/33 ticks  0.3939393939393939 proportion
# San Antonio Spurs: 9/38 ticks  0.23684210526315788 proportion
# Brooklyn Nets: 7/36 ticks  0.19444444444444445 proportion
# Philadelphia 76ers: 14/46 ticks  0.30434782608695654 proportion
# Memphis Grizzlies: 12/39 ticks  0.3076923076923077 proportion
# Detroit Pistons: 13/37 ticks  0.35135135135135137 proportion
# Cleveland Cavaliers: 12/40 ticks  0.3 proportion
# Indiana Pacers: 11/37 ticks  0.2972972972972973 proportion
# Golden State Warriors: 5/31 ticks  0.16129032258064516 proportion
# Dallas Mavericks: 16/41 ticks  0.3902439024390244 proportion
# Denver Nuggets: 11/31 ticks  0.3548387096774194 proportion
# Portland Trail Blazers: 16/39 ticks  0.41025641025641024 proportion
# New York Knicks: 7/30 ticks  0.23333333333333334 proportion
# Washington Wizards: 13/41 ticks  0.3170731707317073 proportion
# Sacramento Kings: 15/33 ticks  0.45454545454545453 proportion
# Atlanta Hawks: 16/35 ticks  0.45714285714285713 proportion
# Charlotte Hornets: 18/37 ticks  0.4864864864864865 proportion
# Houston Rockets: 13/39 ticks  0.3333333333333333 proportion
# Utah Jazz: 10/28 ticks  0.35714285714285715 proportion
# Los Angeles Lakers: 11/33 ticks  0.3333333333333333 proportion
# Boston Celtics: 13/39 ticks  0.3333333333333333 proportion
# Los Angeles Clippers: 16/34 ticks  0.47058823529411764 proportion
# Phoenix Suns: 10/30 ticks  0.3333333333333333 proportion
# Minnesota Timberwolves: 15/35 ticks  0.42857142857142855 proportion
# Toronto Raptors: 19/45 ticks  0.4222222222222222 proportion
# New Orleans Pelicans: 9/35 ticks  0.2571428571428571 proportion
# Miami Heat: 19/37 ticks  0.5135135135135135 proportion
# Milwaukee Bucks: 13/33 ticks  0.3939393939393939 proportion
# Chicago Bulls: 20/40 ticks  0.5 proportion
# Oklahoma City Thunder: 12/44 ticks  0.2727272727272727 proportion
#
#
#  --- 2017 ---
# Orlando Magic: 8/34 ticks  0.23529411764705882 proportion
# San Antonio Spurs: 10/33 ticks  0.30303030303030304 proportion
# Brooklyn Nets: 9/35 ticks  0.2571428571428571 proportion
# Philadelphia 76ers: 8/35 ticks  0.22857142857142856 proportion
# Memphis Grizzlies: 7/32 ticks  0.21875 proportion
# Detroit Pistons: 11/30 ticks  0.36666666666666664 proportion
# Cleveland Cavaliers: 9/33 ticks  0.2727272727272727 proportion
# Indiana Pacers: 13/34 ticks  0.38235294117647056 proportion
# Golden State Warriors: 11/39 ticks  0.28205128205128205 proportion
# Dallas Mavericks: 11/32 ticks  0.34375 proportion
# Denver Nuggets: 14/35 ticks  0.4 proportion
# Portland Trail Blazers: 10/36 ticks  0.2777777777777778 proportion
# New York Knicks: 13/43 ticks  0.3023255813953488 proportion
# Washington Wizards: 15/33 ticks  0.45454545454545453 proportion
# Sacramento Kings: 11/37 ticks  0.2972972972972973 proportion
# Atlanta Hawks: 7/31 ticks  0.22580645161290322 proportion
# Charlotte Hornets: 14/42 ticks  0.3333333333333333 proportion
# Houston Rockets: 5/37 ticks  0.13513513513513514 proportion
# Utah Jazz: 13/40 ticks  0.325 proportion
# Los Angeles Lakers: 8/33 ticks  0.24242424242424243 proportion
# Boston Celtics: 13/42 ticks  0.30952380952380953 proportion
# Los Angeles Clippers: 7/36 ticks  0.19444444444444445 proportion
# Phoenix Suns: 5/45 ticks  0.1111111111111111 proportion
# Minnesota Timberwolves: 9/33 ticks  0.2727272727272727 proportion
# Toronto Raptors: 9/32 ticks  0.28125 proportion
# New Orleans Pelicans: 10/31 ticks  0.3225806451612903 proportion
# Miami Heat: 10/34 ticks  0.29411764705882354 proportion
# Milwaukee Bucks: 13/37 ticks  0.35135135135135137 proportion
# Chicago Bulls: 9/32 ticks  0.28125 proportion
# Oklahoma City Thunder: 12/34 ticks  0.35294117647058826 proportion
#
#
#  --- 2018 ---
# Orlando Magic: 10/30 ticks  0.3333333333333333 proportion
# San Antonio Spurs: 14/40 ticks  0.35 proportion
# Brooklyn Nets: 9/32 ticks  0.28125 proportion
# Philadelphia 76ers: 13/37 ticks  0.35135135135135137 proportion
# Memphis Grizzlies: 9/31 ticks  0.2903225806451613 proportion
# Detroit Pistons: 8/38 ticks  0.21052631578947367 proportion
# Cleveland Cavaliers: 7/43 ticks  0.16279069767441862 proportion
# Indiana Pacers: 8/27 ticks  0.2962962962962963 proportion
# Golden State Warriors: 11/37 ticks  0.2972972972972973 proportion
# Dallas Mavericks: 8/29 ticks  0.27586206896551724 proportion
# Denver Nuggets: 11/39 ticks  0.28205128205128205 proportion
# Portland Trail Blazers: 15/38 ticks  0.39473684210526316 proportion
# New York Knicks: 7/34 ticks  0.20588235294117646 proportion
# Washington Wizards: 11/34 ticks  0.3235294117647059 proportion
# Sacramento Kings: 10/40 ticks  0.25 proportion
# Atlanta Hawks: 11/38 ticks  0.2894736842105263 proportion
# Charlotte Hornets: 9/38 ticks  0.23684210526315788 proportion
# Houston Rockets: 14/36 ticks  0.3888888888888889 proportion
# Utah Jazz: 10/31 ticks  0.3225806451612903 proportion
# Los Angeles Lakers: 12/33 ticks  0.36363636363636365 proportion
# Boston Celtics: 13/30 ticks  0.43333333333333335 proportion
# Los Angeles Clippers: 10/41 ticks  0.24390243902439024 proportion
# Phoenix Suns: 9/34 ticks  0.2647058823529412 proportion
# Minnesota Timberwolves: 9/32 ticks  0.28125 proportion
# Toronto Raptors: 11/39 ticks  0.28205128205128205 proportion
# New Orleans Pelicans: 6/30 ticks  0.2 proportion
# Miami Heat: 11/34 ticks  0.3235294117647059 proportion
# Milwaukee Bucks: 11/40 ticks  0.275 proportion
# Chicago Bulls: 5/34 ticks  0.14705882352941177 proportion
# Oklahoma City Thunder: 14/37 ticks  0.3783783783783784 proportion
#
#
#  --- 2019 ---
# Orlando Magic: 2/22 ticks  0.09090909090909091 proportion
# San Antonio Spurs: 9/17 ticks  0.5294117647058824 proportion
# Brooklyn Nets: 4/21 ticks  0.19047619047619047 proportion
# Philadelphia 76ers: 4/19 ticks  0.21052631578947367 proportion
# Memphis Grizzlies: 6/19 ticks  0.3157894736842105 proportion
# Detroit Pistons: 7/24 ticks  0.2916666666666667 proportion
# Cleveland Cavaliers: 7/25 ticks  0.28 proportion
# Indiana Pacers: 6/24 ticks  0.25 proportion
# Golden State Warriors: 3/19 ticks  0.15789473684210525 proportion
# Dallas Mavericks: 10/24 ticks  0.4166666666666667 proportion
# Denver Nuggets: 8/23 ticks  0.34782608695652173 proportion
# Portland Trail Blazers: 7/19 ticks  0.3684210526315789 proportion
# New York Knicks: 10/26 ticks  0.38461538461538464 proportion
# Washington Wizards: 10/27 ticks  0.37037037037037035 proportion
# Sacramento Kings: 6/22 ticks  0.2727272727272727 proportion
# Atlanta Hawks: 7/23 ticks  0.30434782608695654 proportion
# Charlotte Hornets: 3/21 ticks  0.14285714285714285 proportion
# Houston Rockets: 7/20 ticks  0.35 proportion
# Utah Jazz: 4/22 ticks  0.18181818181818182 proportion
# Los Angeles Lakers: 6/26 ticks  0.23076923076923078 proportion
# Boston Celtics: 4/19 ticks  0.21052631578947367 proportion
# Los Angeles Clippers: 5/22 ticks  0.22727272727272727 proportion
# Phoenix Suns: 9/27 ticks  0.3333333333333333 proportion
# Minnesota Timberwolves: 3/20 ticks  0.15 proportion
# Toronto Raptors: 4/20 ticks  0.2 proportion
# New Orleans Pelicans: 6/19 ticks  0.3157894736842105 proportion
# Miami Heat: 3/19 ticks  0.15789473684210525 proportion
# Milwaukee Bucks: 4/21 ticks  0.19047619047619047 proportion
# Chicago Bulls: 1/20 ticks  0.05 proportion
# Oklahoma City Thunder: 5/24 ticks  0.20833333333333334 proportion

# %%
# Look at a team for a season
team_chosen = 'Miami Heat'
year_chosen = 2018
df_team = pd.DataFrame(columns=X_test_pre_drop.columns.tolist())
for (r, row), inc in zip(X_test_pre_drop.iterrows(), incorrects):
    date_regex = re.match(r'\w+\s(\w+)\s(\d+)\s(\d+)', row['Date'])
    month = date_regex.group(1)
    year = date_regex.group(3)
    which_seas = which_season(year, month)
    if which_seas == year_chosen and inc and (row['Visitor'] == team_chosen or row['Home'] == team_chosen):
        df_team = df_team.append(row, ignore_index=False)
df_team
# Out:
#                  Date                Visitor PTS-V           Home PTS-H W-V  \
# 46    Thu Dec 20 2018        Houston Rockets    99     Miami Heat   101  16
# 516   Mon Feb 25 2019           Phoenix Suns   124     Miami Heat   121  12
# 805   Sat Nov 10 2018     Washington Wizards   116     Miami Heat   110   3
# 1030   Sun Jan 6 2019             Miami Heat    82  Atlanta Hawks   106  19
# 1473  Wed Apr 10 2019             Miami Heat    94  Brooklyn Nets   113  39
# 1508  Wed Nov 14 2018             Miami Heat   120  Brooklyn Nets   107   6
# 1541   Tue Apr 9 2019     Philadelphia 76ers    99     Miami Heat   122  50
# 1614  Thu Jan 10 2019         Boston Celtics    99     Miami Heat   115  25
# 1747  Sat Dec 22 2018        Milwaukee Bucks    87     Miami Heat    94  22
# 1833  Wed Jan 30 2019          Chicago Bulls   105     Miami Heat    89  12
# 2427  Wed Feb 27 2019  Golden State Warriors   125     Miami Heat   126  43
#
#      L-V W-H L-H Rest-V  ... PIE-H PIE-V REB%-H REB%-V  TOV%-H  TOV%-V  TS%-H  \
# 46    15  14  16      1  ...  50.1  49.8   50.9   48.1    14.9    13.5   54.2
# 516   50  26  33      2  ...  50.1  45.0   50.9   46.4    14.9    15.3   54.2
# 805    9   5   7      1  ...  50.1  48.7   50.9   47.7    14.9    13.6   54.2
# 1030  19  12  27      2  ...  46.4  50.1   49.6   50.9    16.2    14.9   55.5
# 1473  43  42  40      1  ...  49.2  50.1   50.1   50.9    14.6    14.9   55.6
# 1508   8   6   9      2  ...  49.2  50.1   50.1   50.9    14.6    14.9   55.6
# 1541  31  39  42      2  ...  50.1  52.9   50.9   51.7    14.9    14.4   54.2
# 1614  16  20  20      1  ...  50.1  53.0   50.9   49.5    14.9    12.7   54.2
# 1747  10  15  16      1  ...  50.1  55.3   50.9   51.6    14.9    13.3   54.2
# 1833  40  24  25      1  ...  50.1  45.3   50.9   48.3    14.9    14.1   54.2
# 2427  18  27  33      2  ...  50.1  54.6   50.9   50.5    14.9    13.9   54.2
#
#       TS%-V  eFG%-H  eFG%-V
# 46     58.1    51.5    54.2
# 516    55.2    51.5    51.4
# 805    56.7    51.5    53.1
# 1030   54.2    52.2    51.5
# 1473   54.2    52.0    51.5
# 1508   54.2    52.0    51.5
# 1541   57.4    51.5    53.2
# 1614   56.7    51.5    53.4
# 1747   58.3    51.5    55.0
# 1833   54.1    51.5    50.5
# 2427   59.6    51.5    56.5
#
# [11 rows x 263 columns]

# %%
# BASELINE

# Look at a team for a season
team_chosen = 'Miami Heat'
year_chosen = 2018
df_team = pd.DataFrame(columns=X_test_pre_drop.columns.tolist())
for (r, row), inc in zip(X_test_pre_drop.iterrows(), incorrects_baseline):
    date_regex = re.match(r'\w+\s(\w+)\s(\d+)\s(\d+)', row['Date'])
    month = date_regex.group(1)
    year = date_regex.group(3)
    which_seas = which_season(year, month)
    if which_seas == year_chosen and inc and (row['Visitor'] == team_chosen or row['Home'] == team_chosen):
        df_team = df_team.append(row, ignore_index=False)
df_team
# Out:
#                  Date                Visitor PTS-V           Home PTS-H W-V  \
# 46    Thu Dec 20 2018        Houston Rockets    99     Miami Heat   101  16
# 516   Mon Feb 25 2019           Phoenix Suns   124     Miami Heat   121  12
# 657    Sat Mar 2 2019          Brooklyn Nets    88     Miami Heat   117  32
# 805   Sat Nov 10 2018     Washington Wizards   116     Miami Heat   110   3
# 1030   Sun Jan 6 2019             Miami Heat    82  Atlanta Hawks   106  19
# 1508  Wed Nov 14 2018             Miami Heat   120  Brooklyn Nets   107   6
# 1541   Tue Apr 9 2019     Philadelphia 76ers    99     Miami Heat   122  50
# 1614  Thu Jan 10 2019         Boston Celtics    99     Miami Heat   115  25
# 1747  Sat Dec 22 2018        Milwaukee Bucks    87     Miami Heat    94  22
# 1833  Wed Jan 30 2019          Chicago Bulls   105     Miami Heat    89  12
# 2427  Wed Feb 27 2019  Golden State Warriors   125     Miami Heat   126  43
#
#      L-V W-H L-H Rest-V  ... PIE-H PIE-V REB%-H REB%-V  TOV%-H  TOV%-V  TS%-H  \
# 46    15  14  16      1  ...  50.1  49.8   50.9   48.1    14.9    13.5   54.2
# 516   50  26  33      2  ...  50.1  45.0   50.9   46.4    14.9    15.3   54.2
# 657   33  28  34      1  ...  50.1  49.2   50.9   50.1    14.9    14.6   54.2
# 805    9   5   7      1  ...  50.1  48.7   50.9   47.7    14.9    13.6   54.2
# 1030  19  12  27      2  ...  46.4  50.1   49.6   50.9    16.2    14.9   55.5
# 1508   8   6   9      2  ...  49.2  50.1   50.1   50.9    14.6    14.9   55.6
# 1541  31  39  42      2  ...  50.1  52.9   50.9   51.7    14.9    14.4   54.2
# 1614  16  20  20      1  ...  50.1  53.0   50.9   49.5    14.9    12.7   54.2
# 1747  10  15  16      1  ...  50.1  55.3   50.9   51.6    14.9    13.3   54.2
# 1833  40  24  25      1  ...  50.1  45.3   50.9   48.3    14.9    14.1   54.2
# 2427  18  27  33      2  ...  50.1  54.6   50.9   50.5    14.9    13.9   54.2
#
#       TS%-V  eFG%-H  eFG%-V
# 46     58.1    51.5    54.2
# 516    55.2    51.5    51.4
# 657    55.6    51.5    52.0
# 805    56.7    51.5    53.1
# 1030   54.2    52.2    51.5
# 1508   54.2    52.0    51.5
# 1541   57.4    51.5    53.2
# 1614   56.7    51.5    53.4
# 1747   58.3    51.5    55.0
# 1833   54.1    51.5    50.5
# 2427   59.6    51.5    56.5
#
# [11 rows x 263 columns]

# %%
# Print
index = 0
for t, p, b in zip(y_test.values.flatten(), y_pred, baseline_preds):
    add_on = 'WRONG' if t != p else ''
    print('{}: real {}  pred {}  baseline: {}  {}'.format(index, t, p, b, add_on))
    index += 1
# Out:
# 0: real 0  pred 0  baseline: 0
# 1: real 1  pred 1  baseline: 1
# 2: real 1  pred 0  baseline: 0  WRONG
# 3: real 0  pred 1  baseline: 1  WRONG
# 4: real 0  pred 0  baseline: 0
# 5: real 0  pred 1  baseline: 1  WRONG
# 6: real 1  pred 1  baseline: 1
# 7: real 0  pred 0  baseline: 0
# 8: real 0  pred 1  baseline: 1  WRONG
# 9: real 1  pred 0  baseline: 0  WRONG
# 10: real 0  pred 0  baseline: 0
# 11: real 0  pred 1  baseline: 0  WRONG
# 12: real 1  pred 0  baseline: 0  WRONG
# 13: real 1  pred 1  baseline: 1
# 14: real 0  pred 1  baseline: 0  WRONG
# 15: real 1  pred 1  baseline: 1
# 16: real 1  pred 0  baseline: 0  WRONG
# 17: real 0  pred 0  baseline: 0
# 18: real 1  pred 1  baseline: 1
# 19: real 1  pred 1  baseline: 1
# 20: real 1  pred 1  baseline: 1
# 21: real 1  pred 1  baseline: 1
# 22: real 1  pred 1  baseline: 1
# 23: real 1  pred 1  baseline: 1
# 24: real 0  pred 0  baseline: 0
# 25: real 0  pred 0  baseline: 0
# 26: real 0  pred 0  baseline: 0
# 27: real 0  pred 1  baseline: 1  WRONG
# 28: real 0  pred 0  baseline: 0
# 29: real 1  pred 1  baseline: 1
# 30: real 1  pred 1  baseline: 1
# 31: real 0  pred 0  baseline: 0
# 32: real 1  pred 1  baseline: 1
# 33: real 1  pred 1  baseline: 1
# 34: real 1  pred 0  baseline: 0  WRONG
# 35: real 1  pred 1  baseline: 1
# 36: real 0  pred 1  baseline: 1  WRONG
# 37: real 1  pred 1  baseline: 1
# 38: real 1  pred 1  baseline: 1
# 39: real 0  pred 1  baseline: 1  WRONG
# 40: real 1  pred 1  baseline: 1
# 41: real 1  pred 1  baseline: 0
# 42: real 1  pred 0  baseline: 0  WRONG
# 43: real 1  pred 0  baseline: 0  WRONG
# 44: real 0  pred 0  baseline: 0
# 45: real 1  pred 1  baseline: 1
# 46: real 1  pred 0  baseline: 0  WRONG
# 47: real 1  pred 1  baseline: 1
# 48: real 1  pred 1  baseline: 1
# 49: real 1  pred 1  baseline: 0
# 50: real 0  pred 1  baseline: 0  WRONG
# 51: real 1  pred 1  baseline: 1
# 52: real 1  pred 0  baseline: 0  WRONG
# 53: real 1  pred 1  baseline: 1
# 54: real 0  pred 1  baseline: 0  WRONG
# 55: real 1  pred 1  baseline: 1
# 56: real 0  pred 1  baseline: 0  WRONG
# 57: real 0  pred 1  baseline: 1  WRONG
# 58: real 0  pred 0  baseline: 0
# 59: real 1  pred 1  baseline: 1
# 60: real 0  pred 0  baseline: 0
# 61: real 0  pred 0  baseline: 0
# 62: real 0  pred 0  baseline: 0
# 63: real 1  pred 1  baseline: 1
# 64: real 1  pred 1  baseline: 1
# 65: real 0  pred 0  baseline: 0
# 66: real 0  pred 0  baseline: 0
# 67: real 0  pred 0  baseline: 0
# 68: real 0  pred 0  baseline: 0
# 69: real 1  pred 1  baseline: 1
# 70: real 1  pred 1  baseline: 1
# 71: real 0  pred 1  baseline: 1  WRONG
# 72: real 1  pred 1  baseline: 1
# 73: real 0  pred 1  baseline: 1  WRONG
# 74: real 1  pred 1  baseline: 1
# 75: real 1  pred 1  baseline: 1
# 76: real 1  pred 1  baseline: 1
# 77: real 0  pred 1  baseline: 1  WRONG
# 78: real 1  pred 1  baseline: 1
# 79: real 0  pred 1  baseline: 1  WRONG
# 80: real 1  pred 1  baseline: 1
# 81: real 0  pred 1  baseline: 1  WRONG
# 82: real 0  pred 0  baseline: 0
# 83: real 1  pred 1  baseline: 1
# 84: real 1  pred 0  baseline: 1  WRONG
# 85: real 1  pred 1  baseline: 1
# 86: real 0  pred 0  baseline: 0
# 87: real 0  pred 0  baseline: 0
# 88: real 0  pred 0  baseline: 0
# 89: real 0  pred 1  baseline: 1  WRONG
# 90: real 0  pred 1  baseline: 1  WRONG
# 91: real 1  pred 0  baseline: 1  WRONG
# 92: real 0  pred 0  baseline: 0
# 93: real 1  pred 1  baseline: 1
# 94: real 1  pred 1  baseline: 1
# 95: real 1  pred 1  baseline: 1
# 96: real 1  pred 1  baseline: 1
# 97: real 1  pred 1  baseline: 1
# 98: real 0  pred 0  baseline: 0
# 99: real 1  pred 1  baseline: 1
# 100: real 0  pred 1  baseline: 1  WRONG
# 101: real 0  pred 0  baseline: 0
# 102: real 0  pred 0  baseline: 0
# 103: real 0  pred 0  baseline: 0
# 104: real 1  pred 1  baseline: 1
# 105: real 0  pred 1  baseline: 0  WRONG
# 106: real 0  pred 0  baseline: 0
# 107: real 0  pred 0  baseline: 0
# 108: real 0  pred 1  baseline: 1  WRONG
# 109: real 1  pred 1  baseline: 1
# 110: real 1  pred 0  baseline: 0  WRONG
# 111: real 0  pred 0  baseline: 0
# 112: real 1  pred 1  baseline: 1
# 113: real 1  pred 1  baseline: 1
# 114: real 0  pred 1  baseline: 1  WRONG
# 115: real 1  pred 1  baseline: 1
# 116: real 1  pred 1  baseline: 1
# 117: real 0  pred 0  baseline: 0
# 118: real 1  pred 1  baseline: 1
# 119: real 1  pred 0  baseline: 0  WRONG
# 120: real 0  pred 0  baseline: 0
# 121: real 1  pred 1  baseline: 1
# 122: real 0  pred 0  baseline: 0
# 123: real 1  pred 1  baseline: 0
# 124: real 0  pred 1  baseline: 0  WRONG
# 125: real 0  pred 1  baseline: 0  WRONG
# 126: real 1  pred 0  baseline: 0  WRONG
# 127: real 0  pred 1  baseline: 1  WRONG
# 128: real 1  pred 1  baseline: 1
# 129: real 1  pred 1  baseline: 1
# 130: real 1  pred 0  baseline: 0  WRONG
# 131: real 1  pred 1  baseline: 1
# 132: real 1  pred 0  baseline: 0  WRONG
# 133: real 1  pred 1  baseline: 1
# 134: real 0  pred 1  baseline: 1  WRONG
# 135: real 1  pred 1  baseline: 1
# 136: real 1  pred 1  baseline: 1
# 137: real 1  pred 1  baseline: 1
# 138: real 1  pred 1  baseline: 0
# 139: real 1  pred 1  baseline: 1
# 140: real 1  pred 1  baseline: 1
# 141: real 0  pred 1  baseline: 0  WRONG
# 142: real 1  pred 1  baseline: 0
# 143: real 1  pred 1  baseline: 1
# 144: real 0  pred 0  baseline: 0
# 145: real 0  pred 0  baseline: 0
# 146: real 0  pred 0  baseline: 0
# 147: real 0  pred 1  baseline: 1  WRONG
# 148: real 1  pred 1  baseline: 1
# 149: real 1  pred 1  baseline: 1
# 150: real 0  pred 0  baseline: 0
# 151: real 1  pred 1  baseline: 0
# 152: real 1  pred 1  baseline: 1
# 153: real 0  pred 0  baseline: 0
# 154: real 0  pred 0  baseline: 0
# 155: real 1  pred 1  baseline: 1
# 156: real 1  pred 1  baseline: 1
# 157: real 0  pred 1  baseline: 0  WRONG
# 158: real 1  pred 1  baseline: 1
# 159: real 0  pred 1  baseline: 0  WRONG
# 160: real 1  pred 0  baseline: 0  WRONG
# 161: real 1  pred 1  baseline: 1
# 162: real 1  pred 1  baseline: 1
# 163: real 1  pred 1  baseline: 1
# 164: real 1  pred 1  baseline: 0
# 165: real 0  pred 1  baseline: 1  WRONG
# 166: real 0  pred 0  baseline: 0
# 167: real 1  pred 1  baseline: 1
# 168: real 1  pred 1  baseline: 1
# 169: real 1  pred 1  baseline: 1
# 170: real 1  pred 1  baseline: 1
# 171: real 1  pred 1  baseline: 1
# 172: real 1  pred 1  baseline: 1
# 173: real 1  pred 0  baseline: 0  WRONG
# 174: real 1  pred 1  baseline: 1
# 175: real 0  pred 1  baseline: 1  WRONG
# 176: real 0  pred 1  baseline: 1  WRONG
# 177: real 1  pred 1  baseline: 0
# 178: real 0  pred 0  baseline: 0
# 179: real 0  pred 0  baseline: 0
# 180: real 0  pred 1  baseline: 0  WRONG
# 181: real 0  pred 1  baseline: 0  WRONG
# 182: real 1  pred 1  baseline: 0
# 183: real 1  pred 1  baseline: 1
# 184: real 0  pred 1  baseline: 0  WRONG
# 185: real 0  pred 1  baseline: 1  WRONG
# 186: real 1  pred 1  baseline: 1
# 187: real 1  pred 1  baseline: 1
# 188: real 1  pred 1  baseline: 0
# 189: real 1  pred 1  baseline: 1
# 190: real 0  pred 0  baseline: 0
# 191: real 1  pred 1  baseline: 1
# 192: real 0  pred 0  baseline: 0
# 193: real 0  pred 1  baseline: 1  WRONG
# 194: real 1  pred 1  baseline: 0
# 195: real 0  pred 0  baseline: 0
# 196: real 1  pred 1  baseline: 1
# 197: real 1  pred 0  baseline: 0  WRONG
# 198: real 1  pred 1  baseline: 0
# 199: real 1  pred 0  baseline: 0  WRONG
# 200: real 1  pred 0  baseline: 0  WRONG
# 201: real 1  pred 1  baseline: 1
# 202: real 1  pred 1  baseline: 1
# 203: real 0  pred 0  baseline: 0
# 204: real 0  pred 0  baseline: 0
# 205: real 1  pred 1  baseline: 1
# 206: real 0  pred 0  baseline: 0
# 207: real 0  pred 0  baseline: 0
# 208: real 0  pred 0  baseline: 0
# 209: real 1  pred 1  baseline: 1
# 210: real 1  pred 1  baseline: 1
# 211: real 1  pred 1  baseline: 0
# 212: real 0  pred 1  baseline: 1  WRONG
# 213: real 1  pred 1  baseline: 1
# 214: real 1  pred 0  baseline: 0  WRONG
# 215: real 1  pred 0  baseline: 0  WRONG
# 216: real 1  pred 1  baseline: 1
# 217: real 1  pred 0  baseline: 0  WRONG
# 218: real 0  pred 1  baseline: 1  WRONG
# 219: real 1  pred 0  baseline: 0  WRONG
# 220: real 0  pred 0  baseline: 0
# 221: real 0  pred 1  baseline: 1  WRONG
# 222: real 1  pred 1  baseline: 0
# 223: real 1  pred 1  baseline: 1
# 224: real 1  pred 0  baseline: 0  WRONG
# 225: real 1  pred 1  baseline: 1
# 226: real 0  pred 0  baseline: 0
# 227: real 1  pred 1  baseline: 1
# 228: real 0  pred 0  baseline: 0
# 229: real 0  pred 1  baseline: 1  WRONG
# 230: real 1  pred 0  baseline: 0  WRONG
# 231: real 1  pred 0  baseline: 0  WRONG
# 232: real 1  pred 1  baseline: 1
# 233: real 1  pred 1  baseline: 1
# 234: real 0  pred 1  baseline: 0  WRONG
# 235: real 1  pred 1  baseline: 1
# 236: real 0  pred 1  baseline: 1  WRONG
# 237: real 0  pred 1  baseline: 0  WRONG
# 238: real 1  pred 1  baseline: 1
# 239: real 0  pred 1  baseline: 0  WRONG
# 240: real 0  pred 0  baseline: 0
# 241: real 1  pred 1  baseline: 1
# 242: real 1  pred 0  baseline: 0  WRONG
# 243: real 0  pred 1  baseline: 1  WRONG
# 244: real 0  pred 1  baseline: 1  WRONG
# 245: real 0  pred 1  baseline: 1  WRONG
# 246: real 1  pred 1  baseline: 1
# 247: real 1  pred 1  baseline: 1
# 248: real 1  pred 1  baseline: 1
# 249: real 1  pred 1  baseline: 1
# 250: real 0  pred 1  baseline: 1  WRONG
# 251: real 1  pred 0  baseline: 0  WRONG
# 252: real 1  pred 1  baseline: 1
# 253: real 0  pred 1  baseline: 0  WRONG
# 254: real 0  pred 0  baseline: 0
# 255: real 1  pred 0  baseline: 1  WRONG
# 256: real 0  pred 1  baseline: 0  WRONG
# 257: real 0  pred 0  baseline: 0
# 258: real 1  pred 0  baseline: 0  WRONG
# 259: real 1  pred 1  baseline: 1
# 260: real 0  pred 1  baseline: 0  WRONG
# 261: real 1  pred 0  baseline: 0  WRONG
# 262: real 1  pred 1  baseline: 1
# 263: real 0  pred 1  baseline: 1  WRONG
# 264: real 1  pred 1  baseline: 1
# 265: real 0  pred 0  baseline: 0
# 266: real 1  pred 1  baseline: 1
# 267: real 0  pred 0  baseline: 0
# 268: real 0  pred 0  baseline: 0
# 269: real 1  pred 0  baseline: 0  WRONG
# 270: real 1  pred 1  baseline: 1
# 271: real 1  pred 1  baseline: 1
# 272: real 1  pred 1  baseline: 1
# 273: real 1  pred 1  baseline: 1
# 274: real 1  pred 1  baseline: 1
# 275: real 1  pred 1  baseline: 1
# 276: real 0  pred 0  baseline: 0
# 277: real 1  pred 1  baseline: 0
# 278: real 0  pred 1  baseline: 1  WRONG
# 279: real 0  pred 1  baseline: 1  WRONG
# 280: real 0  pred 0  baseline: 0
# 281: real 1  pred 1  baseline: 0
# 282: real 0  pred 0  baseline: 0
# 283: real 0  pred 1  baseline: 1  WRONG
# 284: real 1  pred 1  baseline: 1
# 285: real 1  pred 1  baseline: 1
# 286: real 0  pred 1  baseline: 0  WRONG
# 287: real 1  pred 0  baseline: 0  WRONG
# 288: real 1  pred 0  baseline: 0  WRONG
# 289: real 0  pred 0  baseline: 0
# 290: real 1  pred 1  baseline: 1
# 291: real 0  pred 1  baseline: 0  WRONG
# 292: real 1  pred 1  baseline: 0
# 293: real 1  pred 1  baseline: 1
# 294: real 0  pred 0  baseline: 0
# 295: real 0  pred 1  baseline: 1  WRONG
# 296: real 1  pred 1  baseline: 0
# 297: real 1  pred 1  baseline: 1
# 298: real 0  pred 0  baseline: 0
# 299: real 0  pred 1  baseline: 1  WRONG
# 300: real 1  pred 1  baseline: 1
# 301: real 1  pred 1  baseline: 1
# 302: real 1  pred 1  baseline: 1
# 303: real 1  pred 0  baseline: 1  WRONG
# 304: real 0  pred 0  baseline: 0
# 305: real 0  pred 0  baseline: 0
# 306: real 0  pred 1  baseline: 1  WRONG
# 307: real 0  pred 0  baseline: 0
# 308: real 1  pred 1  baseline: 1
# 309: real 1  pred 1  baseline: 1
# 310: real 0  pred 1  baseline: 0  WRONG
# 311: real 1  pred 1  baseline: 1
# 312: real 1  pred 1  baseline: 1
# 313: real 1  pred 1  baseline: 1
# 314: real 0  pred 0  baseline: 0
# 315: real 1  pred 0  baseline: 0  WRONG
# 316: real 0  pred 1  baseline: 0  WRONG
# 317: real 1  pred 1  baseline: 1
# 318: real 0  pred 0  baseline: 0
# 319: real 1  pred 1  baseline: 0
# 320: real 1  pred 1  baseline: 1
# 321: real 0  pred 1  baseline: 0  WRONG
# 322: real 0  pred 1  baseline: 1  WRONG
# 323: real 0  pred 1  baseline: 1  WRONG
# 324: real 1  pred 0  baseline: 0  WRONG
# 325: real 1  pred 0  baseline: 0  WRONG
# 326: real 1  pred 1  baseline: 0
# 327: real 1  pred 1  baseline: 1
# 328: real 0  pred 0  baseline: 0
# 329: real 0  pred 1  baseline: 1  WRONG
# 330: real 1  pred 1  baseline: 1
# 331: real 1  pred 1  baseline: 1
# 332: real 1  pred 1  baseline: 1
# 333: real 1  pred 1  baseline: 1
# 334: real 1  pred 1  baseline: 1
# 335: real 1  pred 1  baseline: 1
# 336: real 0  pred 0  baseline: 0
# 337: real 0  pred 0  baseline: 0
# 338: real 0  pred 0  baseline: 0
# 339: real 0  pred 1  baseline: 1  WRONG
# 340: real 0  pred 1  baseline: 0  WRONG
# 341: real 1  pred 1  baseline: 1
# 342: real 0  pred 0  baseline: 0
# 343: real 0  pred 0  baseline: 0
# 344: real 1  pred 1  baseline: 1
# 345: real 1  pred 1  baseline: 1
# 346: real 0  pred 0  baseline: 0
# 347: real 0  pred 0  baseline: 0
# 348: real 1  pred 1  baseline: 1
# 349: real 0  pred 0  baseline: 0
# 350: real 0  pred 0  baseline: 0
# 351: real 0  pred 0  baseline: 0
# 352: real 0  pred 1  baseline: 0  WRONG
# 353: real 1  pred 1  baseline: 1
# 354: real 0  pred 1  baseline: 0  WRONG
# 355: real 1  pred 0  baseline: 0  WRONG
# 356: real 1  pred 0  baseline: 0  WRONG
# 357: real 0  pred 1  baseline: 1  WRONG
# 358: real 0  pred 0  baseline: 0
# 359: real 0  pred 0  baseline: 0
# 360: real 0  pred 1  baseline: 1  WRONG
# 361: real 1  pred 1  baseline: 1
# 362: real 1  pred 1  baseline: 0
# 363: real 0  pred 0  baseline: 0
# 364: real 1  pred 1  baseline: 0
# 365: real 0  pred 0  baseline: 0
# 366: real 1  pred 1  baseline: 1
# 367: real 0  pred 1  baseline: 0  WRONG
# 368: real 0  pred 1  baseline: 1  WRONG
# 369: real 1  pred 1  baseline: 0
# 370: real 1  pred 1  baseline: 1
# 371: real 0  pred 0  baseline: 0
# 372: real 0  pred 1  baseline: 0  WRONG
# 373: real 1  pred 1  baseline: 1
# 374: real 0  pred 1  baseline: 1  WRONG
# 375: real 1  pred 0  baseline: 0  WRONG
# 376: real 1  pred 1  baseline: 1
# 377: real 0  pred 0  baseline: 0
# 378: real 1  pred 1  baseline: 1
# 379: real 1  pred 1  baseline: 1
# 380: real 1  pred 1  baseline: 1
# 381: real 0  pred 0  baseline: 0
# 382: real 0  pred 0  baseline: 0
# 383: real 1  pred 1  baseline: 1
# 384: real 1  pred 1  baseline: 1
# 385: real 1  pred 1  baseline: 1
# 386: real 1  pred 0  baseline: 0  WRONG
# 387: real 1  pred 1  baseline: 1
# 388: real 0  pred 1  baseline: 0  WRONG
# 389: real 1  pred 1  baseline: 1
# 390: real 0  pred 0  baseline: 0
# 391: real 0  pred 0  baseline: 0
# 392: real 1  pred 1  baseline: 1
# 393: real 1  pred 0  baseline: 0  WRONG
# 394: real 1  pred 0  baseline: 0  WRONG
# 395: real 1  pred 0  baseline: 0  WRONG
# 396: real 0  pred 1  baseline: 1  WRONG
# 397: real 1  pred 1  baseline: 0
# 398: real 1  pred 1  baseline: 1
# 399: real 1  pred 1  baseline: 1
# 400: real 0  pred 0  baseline: 0
# 401: real 0  pred 1  baseline: 1  WRONG
# 402: real 0  pred 1  baseline: 1  WRONG
# 403: real 1  pred 1  baseline: 1
# 404: real 0  pred 0  baseline: 0
# 405: real 1  pred 1  baseline: 0
# 406: real 0  pred 1  baseline: 1  WRONG
# 407: real 1  pred 1  baseline: 1
# 408: real 0  pred 0  baseline: 1
# 409: real 1  pred 0  baseline: 0  WRONG
# 410: real 1  pred 1  baseline: 1
# 411: real 1  pred 1  baseline: 1
# 412: real 1  pred 1  baseline: 1
# 413: real 1  pred 1  baseline: 1
# 414: real 1  pred 1  baseline: 0
# 415: real 0  pred 0  baseline: 1
# 416: real 1  pred 1  baseline: 1
# 417: real 0  pred 0  baseline: 0
# 418: real 1  pred 1  baseline: 0
# 419: real 1  pred 1  baseline: 1
# 420: real 1  pred 1  baseline: 0
# 421: real 0  pred 0  baseline: 0
# 422: real 0  pred 0  baseline: 0
# 423: real 0  pred 0  baseline: 0
# 424: real 1  pred 1  baseline: 0
# 425: real 0  pred 1  baseline: 1  WRONG
# 426: real 1  pred 1  baseline: 1
# 427: real 0  pred 0  baseline: 0
# 428: real 0  pred 1  baseline: 1  WRONG
# 429: real 1  pred 1  baseline: 1
# 430: real 0  pred 1  baseline: 1  WRONG
# 431: real 1  pred 1  baseline: 1
# 432: real 1  pred 1  baseline: 1
# 433: real 0  pred 1  baseline: 0  WRONG
# 434: real 1  pred 1  baseline: 0
# 435: real 0  pred 0  baseline: 0
# 436: real 1  pred 1  baseline: 1
# 437: real 0  pred 1  baseline: 0  WRONG
# 438: real 1  pred 0  baseline: 0  WRONG
# 439: real 0  pred 1  baseline: 1  WRONG
# 440: real 0  pred 0  baseline: 0
# 441: real 1  pred 1  baseline: 0
# 442: real 0  pred 1  baseline: 1  WRONG
# 443: real 0  pred 0  baseline: 0
# 444: real 0  pred 1  baseline: 1  WRONG
# 445: real 1  pred 0  baseline: 0  WRONG
# 446: real 0  pred 0  baseline: 0
# 447: real 1  pred 1  baseline: 1
# 448: real 0  pred 0  baseline: 0
# 449: real 0  pred 0  baseline: 0
# 450: real 0  pred 1  baseline: 0  WRONG
# 451: real 0  pred 1  baseline: 0  WRONG
# 452: real 1  pred 1  baseline: 1
# 453: real 0  pred 0  baseline: 0
# 454: real 0  pred 0  baseline: 0
# 455: real 1  pred 1  baseline: 1
# 456: real 1  pred 1  baseline: 1
# 457: real 0  pred 0  baseline: 0
# 458: real 0  pred 0  baseline: 0
# 459: real 0  pred 0  baseline: 0
# 460: real 1  pred 1  baseline: 0
# 461: real 0  pred 0  baseline: 0
# 462: real 0  pred 0  baseline: 0
# 463: real 1  pred 1  baseline: 1
# 464: real 1  pred 0  baseline: 0  WRONG
# 465: real 0  pred 1  baseline: 1  WRONG
# 466: real 1  pred 1  baseline: 1
# 467: real 1  pred 1  baseline: 0
# 468: real 0  pred 1  baseline: 1  WRONG
# 469: real 0  pred 1  baseline: 0  WRONG
# 470: real 1  pred 0  baseline: 0  WRONG
# 471: real 1  pred 1  baseline: 1
# 472: real 1  pred 1  baseline: 1
# 473: real 1  pred 0  baseline: 0  WRONG
# 474: real 1  pred 1  baseline: 1
# 475: real 0  pred 1  baseline: 1  WRONG
# 476: real 0  pred 0  baseline: 0
# 477: real 1  pred 0  baseline: 0  WRONG
# 478: real 1  pred 1  baseline: 0
# 479: real 0  pred 1  baseline: 1  WRONG
# 480: real 0  pred 1  baseline: 1  WRONG
# 481: real 0  pred 0  baseline: 0
# 482: real 1  pred 0  baseline: 0  WRONG
# 483: real 0  pred 0  baseline: 0
# 484: real 1  pred 1  baseline: 1
# 485: real 0  pred 1  baseline: 0  WRONG
# 486: real 1  pred 1  baseline: 1
# 487: real 1  pred 1  baseline: 1
# 488: real 1  pred 1  baseline: 1
# 489: real 0  pred 1  baseline: 0  WRONG
# 490: real 1  pred 0  baseline: 0  WRONG
# 491: real 1  pred 0  baseline: 1  WRONG
# 492: real 0  pred 0  baseline: 0
# 493: real 1  pred 0  baseline: 0  WRONG
# 494: real 1  pred 0  baseline: 0  WRONG
# 495: real 0  pred 1  baseline: 1  WRONG
# 496: real 0  pred 1  baseline: 0  WRONG
# 497: real 1  pred 0  baseline: 0  WRONG
# 498: real 1  pred 1  baseline: 1
# 499: real 1  pred 0  baseline: 0  WRONG
# 500: real 1  pred 0  baseline: 1  WRONG
# 501: real 0  pred 1  baseline: 0  WRONG
# 502: real 1  pred 1  baseline: 0
# 503: real 1  pred 1  baseline: 0
# 504: real 1  pred 1  baseline: 1
# 505: real 0  pred 1  baseline: 1  WRONG
# 506: real 0  pred 0  baseline: 0
# 507: real 1  pred 1  baseline: 0
# 508: real 0  pred 1  baseline: 1  WRONG
# 509: real 0  pred 0  baseline: 0
# 510: real 1  pred 1  baseline: 0
# 511: real 0  pred 1  baseline: 1  WRONG
# 512: real 0  pred 0  baseline: 0
# 513: real 0  pred 1  baseline: 1  WRONG
# 514: real 0  pred 0  baseline: 0
# 515: real 0  pred 1  baseline: 1  WRONG
# 516: real 0  pred 1  baseline: 1  WRONG
# 517: real 1  pred 1  baseline: 1
# 518: real 1  pred 1  baseline: 1
# 519: real 1  pred 1  baseline: 1
# 520: real 1  pred 1  baseline: 1
# 521: real 1  pred 1  baseline: 1
# 522: real 1  pred 0  baseline: 1  WRONG
# 523: real 0  pred 0  baseline: 0
# 524: real 1  pred 1  baseline: 1
# 525: real 1  pred 1  baseline: 1
# 526: real 0  pred 0  baseline: 0
# 527: real 1  pred 1  baseline: 0
# 528: real 1  pred 1  baseline: 1
# 529: real 0  pred 1  baseline: 0  WRONG
# 530: real 0  pred 1  baseline: 1  WRONG
# 531: real 1  pred 1  baseline: 0
# 532: real 1  pred 1  baseline: 1
# 533: real 0  pred 0  baseline: 0
# 534: real 1  pred 1  baseline: 1
# 535: real 1  pred 0  baseline: 0  WRONG
# 536: real 1  pred 1  baseline: 1
# 537: real 1  pred 1  baseline: 1
# 538: real 1  pred 1  baseline: 1
# 539: real 0  pred 1  baseline: 1  WRONG
# 540: real 1  pred 1  baseline: 1
# 541: real 0  pred 0  baseline: 0
# 542: real 1  pred 1  baseline: 1
# 543: real 1  pred 1  baseline: 1
# 544: real 1  pred 1  baseline: 1
# 545: real 0  pred 0  baseline: 0
# 546: real 0  pred 1  baseline: 0  WRONG
# 547: real 1  pred 1  baseline: 1
# 548: real 0  pred 0  baseline: 0
# 549: real 1  pred 0  baseline: 1  WRONG
# 550: real 0  pred 1  baseline: 1  WRONG
# 551: real 0  pred 0  baseline: 0
# 552: real 1  pred 1  baseline: 0
# 553: real 0  pred 0  baseline: 0
# 554: real 1  pred 1  baseline: 1
# 555: real 1  pred 0  baseline: 0  WRONG
# 556: real 0  pred 0  baseline: 0
# 557: real 0  pred 0  baseline: 0
# 558: real 1  pred 0  baseline: 0  WRONG
# 559: real 0  pred 1  baseline: 0  WRONG
# 560: real 0  pred 0  baseline: 0
# 561: real 1  pred 1  baseline: 1
# 562: real 1  pred 1  baseline: 1
# 563: real 1  pred 1  baseline: 1
# 564: real 0  pred 0  baseline: 0
# 565: real 1  pred 1  baseline: 0
# 566: real 1  pred 1  baseline: 1
# 567: real 0  pred 0  baseline: 0
# 568: real 1  pred 0  baseline: 0  WRONG
# 569: real 1  pred 1  baseline: 0
# 570: real 0  pred 1  baseline: 1  WRONG
# 571: real 1  pred 1  baseline: 1
# 572: real 1  pred 1  baseline: 1
# 573: real 1  pred 1  baseline: 0
# 574: real 1  pred 1  baseline: 1
# 575: real 1  pred 1  baseline: 1
# 576: real 1  pred 1  baseline: 0
# 577: real 1  pred 1  baseline: 1
# 578: real 0  pred 0  baseline: 0
# 579: real 0  pred 0  baseline: 0
# 580: real 0  pred 1  baseline: 1  WRONG
# 581: real 1  pred 1  baseline: 0
# 582: real 0  pred 0  baseline: 0
# 583: real 1  pred 1  baseline: 1
# 584: real 0  pred 1  baseline: 1  WRONG
# 585: real 0  pred 0  baseline: 0
# 586: real 1  pred 1  baseline: 1
# 587: real 0  pred 1  baseline: 0  WRONG
# 588: real 1  pred 1  baseline: 0
# 589: real 1  pred 0  baseline: 0  WRONG
# 590: real 0  pred 0  baseline: 0
# 591: real 1  pred 1  baseline: 1
# 592: real 0  pred 0  baseline: 0
# 593: real 1  pred 1  baseline: 1
# 594: real 1  pred 1  baseline: 1
# 595: real 1  pred 0  baseline: 0  WRONG
# 596: real 1  pred 1  baseline: 0
# 597: real 1  pred 1  baseline: 1
# 598: real 1  pred 1  baseline: 1
# 599: real 0  pred 1  baseline: 1  WRONG
# 600: real 1  pred 1  baseline: 1
# 601: real 1  pred 1  baseline: 1
# 602: real 0  pred 1  baseline: 1  WRONG
# 603: real 1  pred 1  baseline: 1
# 604: real 0  pred 0  baseline: 0
# 605: real 0  pred 1  baseline: 0  WRONG
# 606: real 1  pred 1  baseline: 1
# 607: real 0  pred 1  baseline: 1  WRONG
# 608: real 1  pred 1  baseline: 1
# 609: real 0  pred 1  baseline: 1  WRONG
# 610: real 0  pred 1  baseline: 0  WRONG
# 611: real 1  pred 1  baseline: 1
# 612: real 0  pred 0  baseline: 0
# 613: real 0  pred 1  baseline: 0  WRONG
# 614: real 0  pred 1  baseline: 1  WRONG
# 615: real 0  pred 1  baseline: 0  WRONG
# 616: real 0  pred 1  baseline: 1  WRONG
# 617: real 0  pred 0  baseline: 0
# 618: real 1  pred 1  baseline: 1
# 619: real 1  pred 1  baseline: 1
# 620: real 0  pred 1  baseline: 1  WRONG
# 621: real 0  pred 0  baseline: 0
# 622: real 1  pred 1  baseline: 1
# 623: real 0  pred 1  baseline: 1  WRONG
# 624: real 1  pred 1  baseline: 1
# 625: real 0  pred 1  baseline: 1  WRONG
# 626: real 0  pred 1  baseline: 1  WRONG
# 627: real 1  pred 1  baseline: 1
# 628: real 0  pred 0  baseline: 0
# 629: real 1  pred 1  baseline: 1
# 630: real 1  pred 0  baseline: 1  WRONG
# 631: real 1  pred 1  baseline: 0
# 632: real 0  pred 0  baseline: 0
# 633: real 0  pred 1  baseline: 1  WRONG
# 634: real 0  pred 1  baseline: 1  WRONG
# 635: real 1  pred 1  baseline: 1
# 636: real 0  pred 0  baseline: 1
# 637: real 1  pred 1  baseline: 1
# 638: real 0  pred 1  baseline: 1  WRONG
# 639: real 1  pred 1  baseline: 0
# 640: real 1  pred 1  baseline: 1
# 641: real 0  pred 1  baseline: 1  WRONG
# 642: real 1  pred 1  baseline: 1
# 643: real 0  pred 0  baseline: 0
# 644: real 0  pred 1  baseline: 1  WRONG
# 645: real 0  pred 1  baseline: 0  WRONG
# 646: real 0  pred 1  baseline: 1  WRONG
# 647: real 1  pred 0  baseline: 0  WRONG
# 648: real 1  pred 1  baseline: 1
# 649: real 0  pred 0  baseline: 1
# 650: real 1  pred 1  baseline: 1
# 651: real 0  pred 0  baseline: 0
# 652: real 0  pred 1  baseline: 1  WRONG
# 653: real 1  pred 1  baseline: 1
# 654: real 0  pred 0  baseline: 1
# 655: real 1  pred 0  baseline: 0  WRONG
# 656: real 1  pred 1  baseline: 1
# 657: real 1  pred 1  baseline: 0
# 658: real 1  pred 1  baseline: 1
# 659: real 1  pred 1  baseline: 0
# 660: real 1  pred 1  baseline: 1
# 661: real 1  pred 1  baseline: 0
# 662: real 0  pred 0  baseline: 0
# 663: real 0  pred 1  baseline: 1  WRONG
# 664: real 0  pred 0  baseline: 0
# 665: real 1  pred 1  baseline: 0
# 666: real 0  pred 1  baseline: 0  WRONG
# 667: real 0  pred 0  baseline: 0
# 668: real 1  pred 1  baseline: 1
# 669: real 0  pred 1  baseline: 0  WRONG
# 670: real 1  pred 1  baseline: 1
# 671: real 1  pred 0  baseline: 0  WRONG
# 672: real 1  pred 1  baseline: 1
# 673: real 0  pred 1  baseline: 0  WRONG
# 674: real 1  pred 1  baseline: 1
# 675: real 1  pred 1  baseline: 1
# 676: real 1  pred 1  baseline: 1
# 677: real 0  pred 1  baseline: 1  WRONG
# 678: real 1  pred 1  baseline: 0
# 679: real 0  pred 0  baseline: 0
# 680: real 1  pred 1  baseline: 1
# 681: real 1  pred 0  baseline: 0  WRONG
# 682: real 1  pred 1  baseline: 1
# 683: real 1  pred 1  baseline: 1
# 684: real 0  pred 1  baseline: 0  WRONG
# 685: real 1  pred 1  baseline: 1
# 686: real 0  pred 0  baseline: 0
# 687: real 0  pred 0  baseline: 0
# 688: real 0  pred 1  baseline: 1  WRONG
# 689: real 1  pred 1  baseline: 0
# 690: real 0  pred 0  baseline: 0
# 691: real 1  pred 1  baseline: 0
# 692: real 0  pred 1  baseline: 0  WRONG
# 693: real 1  pred 1  baseline: 1
# 694: real 0  pred 1  baseline: 1  WRONG
# 695: real 1  pred 1  baseline: 0
# 696: real 1  pred 1  baseline: 1
# 697: real 1  pred 0  baseline: 0  WRONG
# 698: real 1  pred 1  baseline: 0
# 699: real 1  pred 1  baseline: 1
# 700: real 1  pred 1  baseline: 1
# 701: real 0  pred 1  baseline: 0  WRONG
# 702: real 0  pred 1  baseline: 0  WRONG
# 703: real 0  pred 0  baseline: 0
# 704: real 1  pred 0  baseline: 1  WRONG
# 705: real 1  pred 1  baseline: 0
# 706: real 1  pred 1  baseline: 0
# 707: real 1  pred 1  baseline: 1
# 708: real 0  pred 0  baseline: 0
# 709: real 1  pred 0  baseline: 0  WRONG
# 710: real 1  pred 1  baseline: 1
# 711: real 1  pred 0  baseline: 0  WRONG
# 712: real 1  pred 0  baseline: 0  WRONG
# 713: real 0  pred 0  baseline: 0
# 714: real 1  pred 1  baseline: 1
# 715: real 0  pred 0  baseline: 0
# 716: real 1  pred 1  baseline: 0
# 717: real 1  pred 1  baseline: 1
# 718: real 0  pred 0  baseline: 0
# 719: real 1  pred 0  baseline: 0  WRONG
# 720: real 1  pred 1  baseline: 0
# 721: real 0  pred 1  baseline: 1  WRONG
# 722: real 1  pred 1  baseline: 1
# 723: real 1  pred 1  baseline: 1
# 724: real 1  pred 1  baseline: 0
# 725: real 1  pred 1  baseline: 1
# 726: real 1  pred 1  baseline: 1
# 727: real 0  pred 0  baseline: 0
# 728: real 1  pred 1  baseline: 1
# 729: real 1  pred 1  baseline: 1
# 730: real 0  pred 1  baseline: 0  WRONG
# 731: real 0  pred 0  baseline: 0
# 732: real 1  pred 1  baseline: 1
# 733: real 1  pred 1  baseline: 0
# 734: real 1  pred 1  baseline: 1
# 735: real 1  pred 0  baseline: 0  WRONG
# 736: real 1  pred 1  baseline: 1
# 737: real 0  pred 0  baseline: 0
# 738: real 0  pred 1  baseline: 1  WRONG
# 739: real 1  pred 1  baseline: 1
# 740: real 0  pred 1  baseline: 1  WRONG
# 741: real 1  pred 1  baseline: 1
# 742: real 1  pred 1  baseline: 1
# 743: real 1  pred 1  baseline: 1
# 744: real 1  pred 1  baseline: 1
# 745: real 1  pred 1  baseline: 1
# 746: real 1  pred 1  baseline: 1
# 747: real 1  pred 0  baseline: 0  WRONG
# 748: real 1  pred 1  baseline: 1
# 749: real 1  pred 1  baseline: 0
# 750: real 0  pred 0  baseline: 0
# 751: real 0  pred 0  baseline: 0
# 752: real 1  pred 1  baseline: 1
# 753: real 1  pred 1  baseline: 1
# 754: real 0  pred 0  baseline: 0
# 755: real 1  pred 1  baseline: 0
# 756: real 1  pred 1  baseline: 0
# 757: real 0  pred 0  baseline: 0
# 758: real 1  pred 1  baseline: 1
# 759: real 0  pred 1  baseline: 0  WRONG
# 760: real 1  pred 1  baseline: 1
# 761: real 1  pred 1  baseline: 1
# 762: real 1  pred 1  baseline: 1
# 763: real 1  pred 1  baseline: 1
# 764: real 0  pred 0  baseline: 0
# 765: real 0  pred 1  baseline: 1  WRONG
# 766: real 0  pred 1  baseline: 1  WRONG
# 767: real 0  pred 0  baseline: 0
# 768: real 0  pred 0  baseline: 0
# 769: real 0  pred 1  baseline: 0  WRONG
# 770: real 1  pred 1  baseline: 0
# 771: real 1  pred 1  baseline: 1
# 772: real 1  pred 1  baseline: 1
# 773: real 1  pred 1  baseline: 0
# 774: real 1  pred 0  baseline: 0  WRONG
# 775: real 1  pred 1  baseline: 0
# 776: real 0  pred 0  baseline: 0
# 777: real 0  pred 0  baseline: 0
# 778: real 0  pred 0  baseline: 0
# 779: real 1  pred 1  baseline: 1
# 780: real 0  pred 1  baseline: 0  WRONG
# 781: real 0  pred 1  baseline: 0  WRONG
# 782: real 0  pred 1  baseline: 1  WRONG
# 783: real 1  pred 1  baseline: 1
# 784: real 0  pred 1  baseline: 0  WRONG
# 785: real 0  pred 1  baseline: 1  WRONG
# 786: real 1  pred 1  baseline: 0
# 787: real 0  pred 0  baseline: 0
# 788: real 0  pred 0  baseline: 0
# 789: real 0  pred 0  baseline: 0
# 790: real 0  pred 0  baseline: 0
# 791: real 1  pred 1  baseline: 1
# 792: real 1  pred 1  baseline: 1
# 793: real 1  pred 1  baseline: 1
# 794: real 1  pred 0  baseline: 0  WRONG
# 795: real 1  pred 1  baseline: 1
# 796: real 1  pred 1  baseline: 1
# 797: real 1  pred 0  baseline: 0  WRONG
# 798: real 0  pred 1  baseline: 1  WRONG
# 799: real 1  pred 1  baseline: 0
# 800: real 1  pred 1  baseline: 1
# 801: real 1  pred 1  baseline: 1
# 802: real 0  pred 0  baseline: 0
# 803: real 0  pred 0  baseline: 0
# 804: real 0  pred 1  baseline: 1  WRONG
# 805: real 0  pred 1  baseline: 1  WRONG
# 806: real 1  pred 1  baseline: 0
# 807: real 0  pred 0  baseline: 0
# 808: real 0  pred 1  baseline: 1  WRONG
# 809: real 0  pred 1  baseline: 1  WRONG
# 810: real 1  pred 1  baseline: 1
# 811: real 1  pred 1  baseline: 1
# 812: real 1  pred 0  baseline: 0  WRONG
# 813: real 1  pred 0  baseline: 1  WRONG
# 814: real 1  pred 1  baseline: 1
# 815: real 1  pred 1  baseline: 0
# 816: real 0  pred 1  baseline: 1  WRONG
# 817: real 1  pred 1  baseline: 1
# 818: real 1  pred 1  baseline: 1
# 819: real 0  pred 1  baseline: 1  WRONG
# 820: real 0  pred 1  baseline: 1  WRONG
# 821: real 0  pred 1  baseline: 1  WRONG
# 822: real 1  pred 1  baseline: 1
# 823: real 1  pred 1  baseline: 1
# 824: real 1  pred 1  baseline: 1
# 825: real 0  pred 1  baseline: 1  WRONG
# 826: real 1  pred 0  baseline: 1  WRONG
# 827: real 0  pred 0  baseline: 0
# 828: real 1  pred 0  baseline: 1  WRONG
# 829: real 0  pred 1  baseline: 0  WRONG
# 830: real 0  pred 0  baseline: 0
# 831: real 1  pred 0  baseline: 0  WRONG
# 832: real 0  pred 0  baseline: 0
# 833: real 0  pred 0  baseline: 0
# 834: real 0  pred 0  baseline: 0
# 835: real 1  pred 1  baseline: 1
# 836: real 1  pred 1  baseline: 1
# 837: real 0  pred 0  baseline: 0
# 838: real 1  pred 1  baseline: 1
# 839: real 1  pred 1  baseline: 1
# 840: real 1  pred 1  baseline: 0
# 841: real 1  pred 0  baseline: 0  WRONG
# 842: real 0  pred 0  baseline: 0
# 843: real 1  pred 0  baseline: 0  WRONG
# 844: real 1  pred 0  baseline: 1  WRONG
# 845: real 1  pred 1  baseline: 1
# 846: real 0  pred 1  baseline: 0  WRONG
# 847: real 1  pred 1  baseline: 1
# 848: real 0  pred 1  baseline: 1  WRONG
# 849: real 1  pred 1  baseline: 0
# 850: real 1  pred 1  baseline: 1
# 851: real 1  pred 1  baseline: 1
# 852: real 1  pred 0  baseline: 1  WRONG
# 853: real 1  pred 1  baseline: 1
# 854: real 0  pred 0  baseline: 0
# 855: real 1  pred 1  baseline: 1
# 856: real 1  pred 1  baseline: 1
# 857: real 0  pred 1  baseline: 0  WRONG
# 858: real 0  pred 0  baseline: 0
# 859: real 1  pred 1  baseline: 1
# 860: real 1  pred 1  baseline: 1
# 861: real 1  pred 0  baseline: 0  WRONG
# 862: real 1  pred 1  baseline: 1
# 863: real 1  pred 1  baseline: 1
# 864: real 1  pred 0  baseline: 0  WRONG
# 865: real 1  pred 0  baseline: 0  WRONG
# 866: real 1  pred 1  baseline: 0
# 867: real 1  pred 1  baseline: 1
# 868: real 0  pred 0  baseline: 0
# 869: real 0  pred 0  baseline: 0
# 870: real 1  pred 0  baseline: 0  WRONG
# 871: real 0  pred 1  baseline: 0  WRONG
# 872: real 0  pred 1  baseline: 1  WRONG
# 873: real 1  pred 0  baseline: 0  WRONG
# 874: real 1  pred 0  baseline: 0  WRONG
# 875: real 0  pred 1  baseline: 0  WRONG
# 876: real 1  pred 0  baseline: 1  WRONG
# 877: real 1  pred 1  baseline: 1
# 878: real 1  pred 1  baseline: 0
# 879: real 1  pred 1  baseline: 1
# 880: real 1  pred 1  baseline: 1
# 881: real 0  pred 1  baseline: 0  WRONG
# 882: real 0  pred 0  baseline: 0
# 883: real 0  pred 0  baseline: 0
# 884: real 1  pred 1  baseline: 1
# 885: real 1  pred 0  baseline: 0  WRONG
# 886: real 0  pred 0  baseline: 0
# 887: real 1  pred 1  baseline: 1
# 888: real 1  pred 0  baseline: 1  WRONG
# 889: real 0  pred 1  baseline: 0  WRONG
# 890: real 1  pred 1  baseline: 0
# 891: real 1  pred 1  baseline: 1
# 892: real 1  pred 1  baseline: 1
# 893: real 0  pred 0  baseline: 0
# 894: real 1  pred 1  baseline: 1
# 895: real 0  pred 1  baseline: 0  WRONG
# 896: real 0  pred 1  baseline: 0  WRONG
# 897: real 1  pred 1  baseline: 1
# 898: real 1  pred 1  baseline: 0
# 899: real 0  pred 0  baseline: 0
# 900: real 1  pred 1  baseline: 1
# 901: real 1  pred 0  baseline: 0  WRONG
# 902: real 1  pred 1  baseline: 0
# 903: real 1  pred 1  baseline: 1
# 904: real 1  pred 1  baseline: 1
# 905: real 0  pred 0  baseline: 0
# 906: real 1  pred 1  baseline: 1
# 907: real 1  pred 1  baseline: 1
# 908: real 0  pred 0  baseline: 0
# 909: real 0  pred 0  baseline: 0
# 910: real 1  pred 1  baseline: 1
# 911: real 0  pred 0  baseline: 0
# 912: real 1  pred 1  baseline: 1
# 913: real 1  pred 1  baseline: 1
# 914: real 0  pred 1  baseline: 1  WRONG
# 915: real 0  pred 1  baseline: 1  WRONG
# 916: real 0  pred 0  baseline: 0
# 917: real 1  pred 1  baseline: 1
# 918: real 1  pred 1  baseline: 1
# 919: real 0  pred 0  baseline: 0
# 920: real 1  pred 1  baseline: 1
# 921: real 1  pred 1  baseline: 1
# 922: real 1  pred 1  baseline: 1
# 923: real 0  pred 0  baseline: 0
# 924: real 0  pred 0  baseline: 1
# 925: real 1  pred 1  baseline: 0
# 926: real 1  pred 1  baseline: 1
# 927: real 0  pred 0  baseline: 0
# 928: real 1  pred 1  baseline: 1
# 929: real 0  pred 0  baseline: 0
# 930: real 0  pred 0  baseline: 0
# 931: real 1  pred 1  baseline: 1
# 932: real 0  pred 1  baseline: 0  WRONG
# 933: real 0  pred 1  baseline: 0  WRONG
# 934: real 0  pred 1  baseline: 0  WRONG
# 935: real 1  pred 1  baseline: 1
# 936: real 1  pred 1  baseline: 1
# 937: real 1  pred 1  baseline: 1
# 938: real 1  pred 1  baseline: 1
# 939: real 1  pred 1  baseline: 1
# 940: real 0  pred 1  baseline: 1  WRONG
# 941: real 1  pred 1  baseline: 1
# 942: real 1  pred 1  baseline: 0
# 943: real 1  pred 1  baseline: 1
# 944: real 0  pred 1  baseline: 0  WRONG
# 945: real 1  pred 1  baseline: 1
# 946: real 0  pred 1  baseline: 1  WRONG
# 947: real 1  pred 1  baseline: 1
# 948: real 0  pred 1  baseline: 0  WRONG
# 949: real 0  pred 0  baseline: 0
# 950: real 1  pred 1  baseline: 0
# 951: real 1  pred 1  baseline: 1
# 952: real 1  pred 0  baseline: 0  WRONG
# 953: real 0  pred 1  baseline: 1  WRONG
# 954: real 0  pred 0  baseline: 0
# 955: real 0  pred 1  baseline: 1  WRONG
# 956: real 1  pred 1  baseline: 1
# 957: real 1  pred 1  baseline: 1
# 958: real 0  pred 1  baseline: 0  WRONG
# 959: real 1  pred 1  baseline: 1
# 960: real 1  pred 1  baseline: 1
# 961: real 1  pred 1  baseline: 0
# 962: real 1  pred 1  baseline: 1
# 963: real 1  pred 1  baseline: 0
# 964: real 1  pred 0  baseline: 0  WRONG
# 965: real 1  pred 1  baseline: 1
# 966: real 1  pred 1  baseline: 1
# 967: real 0  pred 0  baseline: 0
# 968: real 0  pred 0  baseline: 0
# 969: real 0  pred 1  baseline: 0  WRONG
# 970: real 0  pred 0  baseline: 0
# 971: real 1  pred 1  baseline: 1
# 972: real 0  pred 0  baseline: 1
# 973: real 0  pred 0  baseline: 0
# 974: real 0  pred 0  baseline: 0
# 975: real 0  pred 0  baseline: 0
# 976: real 0  pred 1  baseline: 0  WRONG
# 977: real 1  pred 1  baseline: 1
# 978: real 1  pred 1  baseline: 1
# 979: real 1  pred 0  baseline: 0  WRONG
# 980: real 1  pred 1  baseline: 1
# 981: real 1  pred 0  baseline: 0  WRONG
# 982: real 0  pred 0  baseline: 0
# 983: real 1  pred 1  baseline: 1
# 984: real 1  pred 1  baseline: 1
# 985: real 1  pred 1  baseline: 1
# 986: real 0  pred 0  baseline: 0
# 987: real 0  pred 1  baseline: 1  WRONG
# 988: real 1  pred 1  baseline: 0
# 989: real 0  pred 0  baseline: 0
# 990: real 0  pred 0  baseline: 0
# 991: real 0  pred 1  baseline: 0  WRONG
# 992: real 1  pred 1  baseline: 1
# 993: real 0  pred 1  baseline: 1  WRONG
# 994: real 0  pred 0  baseline: 0
# 995: real 1  pred 1  baseline: 1
# 996: real 1  pred 1  baseline: 1
# 997: real 1  pred 1  baseline: 1
# 998: real 1  pred 1  baseline: 1
# 999: real 1  pred 1  baseline: 1
# 1000: real 1  pred 1  baseline: 1
# 1001: real 0  pred 1  baseline: 1  WRONG
# 1002: real 1  pred 0  baseline: 0  WRONG
# 1003: real 1  pred 1  baseline: 0
# 1004: real 0  pred 0  baseline: 0
# 1005: real 1  pred 1  baseline: 1
# 1006: real 0  pred 0  baseline: 0
# 1007: real 1  pred 0  baseline: 1  WRONG
# 1008: real 1  pred 1  baseline: 1
# 1009: real 0  pred 0  baseline: 0
# 1010: real 0  pred 0  baseline: 0
# 1011: real 1  pred 1  baseline: 0
# 1012: real 0  pred 0  baseline: 0
# 1013: real 1  pred 1  baseline: 1
# 1014: real 0  pred 1  baseline: 0  WRONG
# 1015: real 1  pred 0  baseline: 0  WRONG
# 1016: real 1  pred 1  baseline: 1
# 1017: real 1  pred 1  baseline: 1
# 1018: real 1  pred 1  baseline: 1
# 1019: real 0  pred 0  baseline: 0
# 1020: real 1  pred 1  baseline: 1
# 1021: real 0  pred 1  baseline: 1  WRONG
# 1022: real 1  pred 0  baseline: 0  WRONG
# 1023: real 1  pred 1  baseline: 1
# 1024: real 0  pred 0  baseline: 0
# 1025: real 1  pred 1  baseline: 1
# 1026: real 1  pred 1  baseline: 1
# 1027: real 0  pred 1  baseline: 0  WRONG
# 1028: real 1  pred 1  baseline: 1
# 1029: real 1  pred 1  baseline: 1
# 1030: real 1  pred 0  baseline: 0  WRONG
# 1031: real 1  pred 1  baseline: 1
# 1032: real 0  pred 0  baseline: 0
# 1033: real 1  pred 1  baseline: 1
# 1034: real 1  pred 0  baseline: 0  WRONG
# 1035: real 1  pred 1  baseline: 0
# 1036: real 1  pred 1  baseline: 1
# 1037: real 1  pred 0  baseline: 0  WRONG
# 1038: real 0  pred 0  baseline: 0
# 1039: real 0  pred 1  baseline: 1  WRONG
# 1040: real 1  pred 1  baseline: 1
# 1041: real 0  pred 1  baseline: 0  WRONG
# 1042: real 0  pred 0  baseline: 1
# 1043: real 1  pred 0  baseline: 0  WRONG
# 1044: real 0  pred 0  baseline: 0
# 1045: real 1  pred 1  baseline: 1
# 1046: real 0  pred 1  baseline: 0  WRONG
# 1047: real 1  pred 1  baseline: 1
# 1048: real 1  pred 1  baseline: 1
# 1049: real 1  pred 0  baseline: 0  WRONG
# 1050: real 0  pred 0  baseline: 0
# 1051: real 1  pred 1  baseline: 0
# 1052: real 1  pred 1  baseline: 1
# 1053: real 0  pred 1  baseline: 0  WRONG
# 1054: real 0  pred 1  baseline: 0  WRONG
# 1055: real 1  pred 1  baseline: 1
# 1056: real 0  pred 1  baseline: 1  WRONG
# 1057: real 0  pred 1  baseline: 0  WRONG
# 1058: real 1  pred 1  baseline: 1
# 1059: real 0  pred 0  baseline: 1
# 1060: real 1  pred 1  baseline: 0
# 1061: real 1  pred 1  baseline: 1
# 1062: real 1  pred 0  baseline: 0  WRONG
# 1063: real 1  pred 0  baseline: 1  WRONG
# 1064: real 1  pred 1  baseline: 1
# 1065: real 0  pred 0  baseline: 0
# 1066: real 1  pred 1  baseline: 1
# 1067: real 0  pred 0  baseline: 0
# 1068: real 1  pred 1  baseline: 1
# 1069: real 0  pred 0  baseline: 0
# 1070: real 1  pred 0  baseline: 0  WRONG
# 1071: real 1  pred 1  baseline: 1
# 1072: real 0  pred 1  baseline: 1  WRONG
# 1073: real 1  pred 1  baseline: 1
# 1074: real 1  pred 1  baseline: 1
# 1075: real 0  pred 0  baseline: 1
# 1076: real 0  pred 1  baseline: 0  WRONG
# 1077: real 1  pred 1  baseline: 1
# 1078: real 1  pred 0  baseline: 0  WRONG
# 1079: real 1  pred 1  baseline: 1
# 1080: real 1  pred 1  baseline: 1
# 1081: real 0  pred 1  baseline: 0  WRONG
# 1082: real 1  pred 1  baseline: 1
# 1083: real 1  pred 1  baseline: 1
# 1084: real 1  pred 1  baseline: 1
# 1085: real 0  pred 0  baseline: 0
# 1086: real 1  pred 1  baseline: 1
# 1087: real 1  pred 1  baseline: 1
# 1088: real 0  pred 0  baseline: 0
# 1089: real 1  pred 1  baseline: 1
# 1090: real 1  pred 1  baseline: 1
# 1091: real 0  pred 0  baseline: 0
# 1092: real 1  pred 1  baseline: 1
# 1093: real 1  pred 1  baseline: 0
# 1094: real 0  pred 1  baseline: 1  WRONG
# 1095: real 0  pred 1  baseline: 1  WRONG
# 1096: real 1  pred 1  baseline: 1
# 1097: real 1  pred 1  baseline: 0
# 1098: real 1  pred 1  baseline: 1
# 1099: real 1  pred 0  baseline: 0  WRONG
# 1100: real 0  pred 0  baseline: 1
# 1101: real 0  pred 0  baseline: 0
# 1102: real 1  pred 1  baseline: 1
# 1103: real 1  pred 1  baseline: 0
# 1104: real 0  pred 0  baseline: 0
# 1105: real 1  pred 1  baseline: 1
# 1106: real 1  pred 1  baseline: 1
# 1107: real 0  pred 0  baseline: 0
# 1108: real 1  pred 1  baseline: 1
# 1109: real 0  pred 1  baseline: 0  WRONG
# 1110: real 0  pred 0  baseline: 0
# 1111: real 1  pred 1  baseline: 1
# 1112: real 1  pred 1  baseline: 1
# 1113: real 1  pred 1  baseline: 1
# 1114: real 1  pred 0  baseline: 0  WRONG
# 1115: real 1  pred 1  baseline: 1
# 1116: real 1  pred 1  baseline: 1
# 1117: real 1  pred 0  baseline: 0  WRONG
# 1118: real 0  pred 1  baseline: 1  WRONG
# 1119: real 1  pred 1  baseline: 1
# 1120: real 0  pred 1  baseline: 1  WRONG
# 1121: real 1  pred 1  baseline: 1
# 1122: real 0  pred 1  baseline: 1  WRONG
# 1123: real 0  pred 1  baseline: 1  WRONG
# 1124: real 1  pred 1  baseline: 1
# 1125: real 0  pred 1  baseline: 1  WRONG
# 1126: real 0  pred 1  baseline: 0  WRONG
# 1127: real 1  pred 1  baseline: 1
# 1128: real 0  pred 1  baseline: 1  WRONG
# 1129: real 1  pred 0  baseline: 0  WRONG
# 1130: real 0  pred 1  baseline: 0  WRONG
# 1131: real 0  pred 1  baseline: 1  WRONG
# 1132: real 0  pred 0  baseline: 0
# 1133: real 1  pred 1  baseline: 1
# 1134: real 1  pred 1  baseline: 1
# 1135: real 0  pred 1  baseline: 0  WRONG
# 1136: real 0  pred 1  baseline: 1  WRONG
# 1137: real 1  pred 1  baseline: 1
# 1138: real 1  pred 1  baseline: 1
# 1139: real 0  pred 1  baseline: 1  WRONG
# 1140: real 1  pred 1  baseline: 1
# 1141: real 1  pred 1  baseline: 1
# 1142: real 1  pred 1  baseline: 1
# 1143: real 1  pred 1  baseline: 1
# 1144: real 1  pred 1  baseline: 1
# 1145: real 1  pred 0  baseline: 0  WRONG
# 1146: real 0  pred 0  baseline: 0
# 1147: real 1  pred 0  baseline: 0  WRONG
# 1148: real 1  pred 1  baseline: 1
# 1149: real 0  pred 0  baseline: 0
# 1150: real 1  pred 1  baseline: 1
# 1151: real 1  pred 1  baseline: 1
# 1152: real 1  pred 1  baseline: 1
# 1153: real 1  pred 1  baseline: 1
# 1154: real 1  pred 1  baseline: 1
# 1155: real 1  pred 1  baseline: 1
# 1156: real 1  pred 0  baseline: 0  WRONG
# 1157: real 0  pred 0  baseline: 0
# 1158: real 0  pred 0  baseline: 0
# 1159: real 1  pred 0  baseline: 0  WRONG
# 1160: real 1  pred 0  baseline: 0  WRONG
# 1161: real 1  pred 1  baseline: 1
# 1162: real 0  pred 1  baseline: 1  WRONG
# 1163: real 1  pred 1  baseline: 0
# 1164: real 0  pred 0  baseline: 0
# 1165: real 1  pred 1  baseline: 1
# 1166: real 1  pred 1  baseline: 1
# 1167: real 0  pred 0  baseline: 0
# 1168: real 1  pred 1  baseline: 1
# 1169: real 0  pred 0  baseline: 0
# 1170: real 1  pred 1  baseline: 1
# 1171: real 1  pred 1  baseline: 0
# 1172: real 0  pred 1  baseline: 1  WRONG
# 1173: real 1  pred 1  baseline: 0
# 1174: real 0  pred 1  baseline: 1  WRONG
# 1175: real 0  pred 0  baseline: 0
# 1176: real 1  pred 1  baseline: 1
# 1177: real 0  pred 1  baseline: 1  WRONG
# 1178: real 0  pred 1  baseline: 1  WRONG
# 1179: real 1  pred 1  baseline: 0
# 1180: real 1  pred 1  baseline: 1
# 1181: real 1  pred 1  baseline: 1
# 1182: real 0  pred 1  baseline: 0  WRONG
# 1183: real 0  pred 0  baseline: 0
# 1184: real 0  pred 0  baseline: 0
# 1185: real 0  pred 0  baseline: 1
# 1186: real 0  pred 0  baseline: 0
# 1187: real 1  pred 1  baseline: 0
# 1188: real 1  pred 0  baseline: 0  WRONG
# 1189: real 1  pred 1  baseline: 1
# 1190: real 1  pred 1  baseline: 1
# 1191: real 1  pred 0  baseline: 1  WRONG
# 1192: real 1  pred 1  baseline: 1
# 1193: real 0  pred 1  baseline: 1  WRONG
# 1194: real 1  pred 1  baseline: 1
# 1195: real 1  pred 1  baseline: 1
# 1196: real 1  pred 1  baseline: 1
# 1197: real 1  pred 1  baseline: 1
# 1198: real 0  pred 0  baseline: 0
# 1199: real 1  pred 1  baseline: 1
# 1200: real 1  pred 1  baseline: 1
# 1201: real 0  pred 1  baseline: 0  WRONG
# 1202: real 0  pred 1  baseline: 1  WRONG
# 1203: real 0  pred 1  baseline: 0  WRONG
# 1204: real 1  pred 1  baseline: 0
# 1205: real 1  pred 0  baseline: 0  WRONG
# 1206: real 1  pred 1  baseline: 1
# 1207: real 1  pred 1  baseline: 1
# 1208: real 0  pred 1  baseline: 0  WRONG
# 1209: real 1  pred 1  baseline: 0
# 1210: real 0  pred 1  baseline: 1  WRONG
# 1211: real 1  pred 1  baseline: 1
# 1212: real 0  pred 0  baseline: 0
# 1213: real 0  pred 0  baseline: 0
# 1214: real 1  pred 1  baseline: 1
# 1215: real 0  pred 0  baseline: 0
# 1216: real 1  pred 1  baseline: 0
# 1217: real 0  pred 0  baseline: 0
# 1218: real 1  pred 1  baseline: 1
# 1219: real 0  pred 0  baseline: 0
# 1220: real 0  pred 1  baseline: 0  WRONG
# 1221: real 0  pred 0  baseline: 0
# 1222: real 1  pred 1  baseline: 0
# 1223: real 0  pred 1  baseline: 1  WRONG
# 1224: real 1  pred 0  baseline: 0  WRONG
# 1225: real 1  pred 1  baseline: 1
# 1226: real 1  pred 1  baseline: 1
# 1227: real 1  pred 1  baseline: 0
# 1228: real 1  pred 1  baseline: 1
# 1229: real 0  pred 1  baseline: 1  WRONG
# 1230: real 0  pred 1  baseline: 1  WRONG
# 1231: real 0  pred 1  baseline: 0  WRONG
# 1232: real 0  pred 0  baseline: 0
# 1233: real 0  pred 0  baseline: 0
# 1234: real 1  pred 1  baseline: 1
# 1235: real 1  pred 1  baseline: 1
# 1236: real 1  pred 1  baseline: 1
# 1237: real 0  pred 0  baseline: 0
# 1238: real 1  pred 0  baseline: 0  WRONG
# 1239: real 1  pred 0  baseline: 0  WRONG
# 1240: real 1  pred 1  baseline: 0
# 1241: real 1  pred 1  baseline: 1
# 1242: real 0  pred 0  baseline: 0
# 1243: real 1  pred 0  baseline: 1  WRONG
# 1244: real 1  pred 1  baseline: 1
# 1245: real 1  pred 1  baseline: 0
# 1246: real 1  pred 1  baseline: 1
# 1247: real 1  pred 1  baseline: 1
# 1248: real 1  pred 1  baseline: 0
# 1249: real 1  pred 1  baseline: 0
# 1250: real 1  pred 1  baseline: 0
# 1251: real 1  pred 1  baseline: 1
# 1252: real 0  pred 0  baseline: 0
# 1253: real 1  pred 1  baseline: 1
# 1254: real 1  pred 1  baseline: 1
# 1255: real 1  pred 1  baseline: 1
# 1256: real 0  pred 0  baseline: 0
# 1257: real 1  pred 1  baseline: 1
# 1258: real 0  pred 0  baseline: 1
# 1259: real 0  pred 1  baseline: 0  WRONG
# 1260: real 0  pred 1  baseline: 0  WRONG
# 1261: real 1  pred 1  baseline: 1
# 1262: real 1  pred 0  baseline: 0  WRONG
# 1263: real 0  pred 1  baseline: 0  WRONG
# 1264: real 0  pred 0  baseline: 0
# 1265: real 1  pred 1  baseline: 1
# 1266: real 0  pred 1  baseline: 1  WRONG
# 1267: real 1  pred 1  baseline: 0
# 1268: real 1  pred 1  baseline: 1
# 1269: real 0  pred 1  baseline: 1  WRONG
# 1270: real 1  pred 1  baseline: 1
# 1271: real 0  pred 0  baseline: 0
# 1272: real 1  pred 1  baseline: 1
# 1273: real 0  pred 1  baseline: 1  WRONG
# 1274: real 1  pred 1  baseline: 1
# 1275: real 0  pred 0  baseline: 0
# 1276: real 0  pred 0  baseline: 0
# 1277: real 1  pred 1  baseline: 0
# 1278: real 0  pred 1  baseline: 0  WRONG
# 1279: real 1  pred 1  baseline: 1
# 1280: real 1  pred 1  baseline: 1
# 1281: real 1  pred 1  baseline: 1
# 1282: real 1  pred 1  baseline: 1
# 1283: real 1  pred 1  baseline: 1
# 1284: real 0  pred 0  baseline: 0
# 1285: real 0  pred 0  baseline: 0
# 1286: real 0  pred 0  baseline: 0
# 1287: real 0  pred 1  baseline: 0  WRONG
# 1288: real 1  pred 1  baseline: 1
# 1289: real 1  pred 0  baseline: 0  WRONG
# 1290: real 1  pred 1  baseline: 1
# 1291: real 0  pred 0  baseline: 0
# 1292: real 0  pred 1  baseline: 1  WRONG
# 1293: real 0  pred 1  baseline: 0  WRONG
# 1294: real 0  pred 0  baseline: 0
# 1295: real 1  pred 1  baseline: 1
# 1296: real 1  pred 1  baseline: 0
# 1297: real 1  pred 1  baseline: 1
# 1298: real 1  pred 1  baseline: 1
# 1299: real 0  pred 1  baseline: 1  WRONG
# 1300: real 0  pred 1  baseline: 1  WRONG
# 1301: real 1  pred 1  baseline: 1
# 1302: real 0  pred 1  baseline: 1  WRONG
# 1303: real 1  pred 1  baseline: 1
# 1304: real 1  pred 0  baseline: 0  WRONG
# 1305: real 1  pred 1  baseline: 1
# 1306: real 1  pred 0  baseline: 0  WRONG
# ...
# 2055: real 1  pred 1  baseline: 1
# 2056: real 0  pred 0  baseline: 0
# 2057: real 0  pred 1  baseline: 0  WRONG
# 2058: real 1  pred 0  baseline: 1  WRONG
# 2059: real 0  pred 1  baseline: 0  WRONG
# 2060: real 1  pred 1  baseline: 1
# 2061: real 1  pred 1  baseline: 1
# 2062: real 1  pred 1  baseline: 1
# 2063: real 0  pred 1  baseline: 1  WRONG
# 2064: real 0  pred 1  baseline: 1  WRONG
# 2065: real 1  pred 1  baseline: 1
# 2066: real 0  pred 1  baseline: 0  WRONG
# 2067: real 1  pred 1  baseline: 1
# 2068: real 1  pred 0  baseline: 0  WRONG
# 2069: real 1  pred 1  baseline: 1
# 2070: real 0  pred 1  baseline: 0  WRONG
# 2071: real 0  pred 0  baseline: 0
# 2072: real 0  pred 1  baseline: 0  WRONG
# 2073: real 1  pred 0  baseline: 0  WRONG
# 2074: real 1  pred 1  baseline: 1
# 2075: real 1  pred 1  baseline: 0
# 2076: real 0  pred 0  baseline: 0
# 2077: real 1  pred 1  baseline: 0
# 2078: real 1  pred 1  baseline: 1
# 2079: real 1  pred 1  baseline: 1
# 2080: real 0  pred 1  baseline: 1  WRONG
# 2081: real 1  pred 1  baseline: 1
# 2082: real 1  pred 1  baseline: 1
# 2083: real 0  pred 1  baseline: 0  WRONG
# 2084: real 0  pred 1  baseline: 0  WRONG
# 2085: real 0  pred 1  baseline: 0  WRONG
# 2086: real 0  pred 0  baseline: 0
# 2087: real 1  pred 1  baseline: 1
# 2088: real 1  pred 1  baseline: 0
# 2089: real 0  pred 1  baseline: 1  WRONG
# 2090: real 1  pred 0  baseline: 0  WRONG
# 2091: real 1  pred 1  baseline: 1
# 2092: real 0  pred 1  baseline: 0  WRONG
# 2093: real 1  pred 1  baseline: 0
# 2094: real 0  pred 0  baseline: 0
# 2095: real 1  pred 1  baseline: 1
# 2096: real 0  pred 1  baseline: 1  WRONG
# 2097: real 0  pred 1  baseline: 0  WRONG
# 2098: real 0  pred 0  baseline: 0
# 2099: real 1  pred 1  baseline: 0
# 2100: real 1  pred 1  baseline: 1
# 2101: real 1  pred 1  baseline: 0
# 2102: real 0  pred 0  baseline: 0
# 2103: real 1  pred 1  baseline: 1
# 2104: real 1  pred 1  baseline: 1
# 2105: real 0  pred 0  baseline: 0
# 2106: real 0  pred 0  baseline: 0
# 2107: real 0  pred 1  baseline: 0  WRONG
# 2108: real 1  pred 1  baseline: 1
# 2109: real 0  pred 0  baseline: 1
# 2110: real 1  pred 0  baseline: 0  WRONG
# 2111: real 0  pred 1  baseline: 1  WRONG
# 2112: real 1  pred 1  baseline: 1
# 2113: real 1  pred 1  baseline: 1
# 2114: real 0  pred 0  baseline: 0
# 2115: real 1  pred 1  baseline: 1
# 2116: real 0  pred 1  baseline: 1  WRONG
# 2117: real 0  pred 0  baseline: 0
# 2118: real 0  pred 0  baseline: 0
# 2119: real 1  pred 1  baseline: 1
# 2120: real 1  pred 1  baseline: 1
# 2121: real 1  pred 1  baseline: 1
# 2122: real 1  pred 1  baseline: 1
# 2123: real 0  pred 1  baseline: 1  WRONG
# 2124: real 1  pred 0  baseline: 0  WRONG
# 2125: real 0  pred 0  baseline: 0
# 2126: real 0  pred 0  baseline: 0
# 2127: real 0  pred 1  baseline: 1  WRONG
# 2128: real 1  pred 1  baseline: 1
# 2129: real 0  pred 0  baseline: 0
# 2130: real 0  pred 0  baseline: 0
# 2131: real 1  pred 1  baseline: 1
# 2132: real 1  pred 1  baseline: 1
# 2133: real 0  pred 0  baseline: 1
# 2134: real 1  pred 0  baseline: 0  WRONG
# 2135: real 1  pred 1  baseline: 0
# 2136: real 1  pred 0  baseline: 0  WRONG
# 2137: real 1  pred 0  baseline: 0  WRONG
# 2138: real 1  pred 1  baseline: 1
# 2139: real 1  pred 1  baseline: 1
# 2140: real 0  pred 0  baseline: 0
# 2141: real 0  pred 1  baseline: 1  WRONG
# 2142: real 1  pred 1  baseline: 1
# 2143: real 1  pred 1  baseline: 0
# 2144: real 0  pred 1  baseline: 0  WRONG
# 2145: real 0  pred 0  baseline: 0
# 2146: real 0  pred 1  baseline: 1  WRONG
# 2147: real 1  pred 1  baseline: 1
# 2148: real 1  pred 1  baseline: 1
# 2149: real 1  pred 1  baseline: 0
# 2150: real 1  pred 1  baseline: 1
# 2151: real 1  pred 1  baseline: 1
# 2152: real 1  pred 0  baseline: 0  WRONG
# 2153: real 1  pred 1  baseline: 1
# 2154: real 0  pred 0  baseline: 0
# 2155: real 0  pred 1  baseline: 0  WRONG
# 2156: real 1  pred 1  baseline: 1
# 2157: real 1  pred 0  baseline: 0  WRONG
# 2158: real 1  pred 1  baseline: 1
# 2159: real 0  pred 0  baseline: 0
# 2160: real 1  pred 1  baseline: 1
# 2161: real 0  pred 0  baseline: 1
# 2162: real 1  pred 1  baseline: 1
# 2163: real 0  pred 1  baseline: 1  WRONG
# 2164: real 0  pred 0  baseline: 0
# 2165: real 0  pred 0  baseline: 0
# 2166: real 1  pred 1  baseline: 1
# 2167: real 1  pred 1  baseline: 1
# 2168: real 1  pred 1  baseline: 1
# 2169: real 1  pred 1  baseline: 0
# 2170: real 1  pred 0  baseline: 0  WRONG
# 2171: real 1  pred 1  baseline: 1
# 2172: real 1  pred 0  baseline: 0  WRONG
# 2173: real 1  pred 1  baseline: 1
# 2174: real 1  pred 1  baseline: 1
# 2175: real 1  pred 0  baseline: 0  WRONG
# 2176: real 0  pred 0  baseline: 0
# 2177: real 0  pred 1  baseline: 1  WRONG
# 2178: real 1  pred 0  baseline: 0  WRONG
# 2179: real 0  pred 0  baseline: 0
# 2180: real 1  pred 1  baseline: 1
# 2181: real 0  pred 1  baseline: 1  WRONG
# 2182: real 0  pred 0  baseline: 0
# 2183: real 1  pred 1  baseline: 0
# 2184: real 1  pred 0  baseline: 0  WRONG
# 2185: real 0  pred 1  baseline: 1  WRONG
# 2186: real 1  pred 1  baseline: 0
# 2187: real 1  pred 0  baseline: 0  WRONG
# 2188: real 0  pred 0  baseline: 0
# 2189: real 1  pred 1  baseline: 1
# 2190: real 1  pred 0  baseline: 0  WRONG
# 2191: real 0  pred 1  baseline: 1  WRONG
# 2192: real 0  pred 1  baseline: 1  WRONG
# 2193: real 0  pred 0  baseline: 0
# 2194: real 0  pred 1  baseline: 1  WRONG
# 2195: real 1  pred 1  baseline: 1
# 2196: real 1  pred 1  baseline: 1
# 2197: real 1  pred 1  baseline: 1
# 2198: real 1  pred 1  baseline: 1
# 2199: real 1  pred 1  baseline: 0
# 2200: real 0  pred 0  baseline: 0
# 2201: real 0  pred 0  baseline: 0
# 2202: real 1  pred 1  baseline: 1
# 2203: real 1  pred 0  baseline: 1  WRONG
# 2204: real 0  pred 1  baseline: 0  WRONG
# 2205: real 1  pred 0  baseline: 1  WRONG
# 2206: real 0  pred 1  baseline: 0  WRONG
# 2207: real 0  pred 0  baseline: 0
# 2208: real 0  pred 0  baseline: 0
# 2209: real 0  pred 0  baseline: 0
# 2210: real 1  pred 1  baseline: 1
# 2211: real 1  pred 1  baseline: 0
# 2212: real 0  pred 0  baseline: 0
# 2213: real 1  pred 1  baseline: 1
# 2214: real 1  pred 1  baseline: 1
# 2215: real 1  pred 1  baseline: 1
# 2216: real 0  pred 0  baseline: 0
# 2217: real 1  pred 1  baseline: 0
# 2218: real 0  pred 1  baseline: 1  WRONG
# 2219: real 0  pred 0  baseline: 0
# 2220: real 0  pred 0  baseline: 0
# 2221: real 0  pred 1  baseline: 1  WRONG
# 2222: real 1  pred 1  baseline: 1
# 2223: real 0  pred 1  baseline: 0  WRONG
# 2224: real 0  pred 0  baseline: 0
# 2225: real 1  pred 1  baseline: 1
# 2226: real 1  pred 1  baseline: 0
# 2227: real 0  pred 1  baseline: 1  WRONG
# 2228: real 0  pred 0  baseline: 0
# 2229: real 1  pred 0  baseline: 1  WRONG
# 2230: real 1  pred 1  baseline: 0
# 2231: real 1  pred 1  baseline: 0
# 2232: real 0  pred 1  baseline: 1  WRONG
# 2233: real 0  pred 0  baseline: 0
# 2234: real 0  pred 0  baseline: 0
# 2235: real 0  pred 0  baseline: 0
# 2236: real 1  pred 1  baseline: 1
# 2237: real 1  pred 1  baseline: 1
# 2238: real 1  pred 1  baseline: 1
# 2239: real 1  pred 1  baseline: 1
# 2240: real 1  pred 0  baseline: 0  WRONG
# 2241: real 0  pred 1  baseline: 1  WRONG
# 2242: real 1  pred 1  baseline: 1
# 2243: real 1  pred 1  baseline: 1
# 2244: real 1  pred 1  baseline: 1
# 2245: real 1  pred 0  baseline: 0  WRONG
# 2246: real 0  pred 0  baseline: 0
# 2247: real 1  pred 1  baseline: 1
# 2248: real 1  pred 0  baseline: 0  WRONG
# 2249: real 0  pred 0  baseline: 0
# 2250: real 1  pred 0  baseline: 1  WRONG
# 2251: real 1  pred 1  baseline: 1
# 2252: real 1  pred 1  baseline: 1
# 2253: real 1  pred 1  baseline: 1
# 2254: real 0  pred 0  baseline: 0
# 2255: real 1  pred 1  baseline: 1
# 2256: real 0  pred 0  baseline: 0
# 2257: real 1  pred 1  baseline: 1
# 2258: real 0  pred 0  baseline: 0
# 2259: real 0  pred 0  baseline: 0
# 2260: real 0  pred 0  baseline: 0
# 2261: real 1  pred 1  baseline: 1
# 2262: real 1  pred 1  baseline: 1
# 2263: real 0  pred 1  baseline: 1  WRONG
# 2264: real 1  pred 1  baseline: 1
# 2265: real 0  pred 1  baseline: 0  WRONG
# 2266: real 1  pred 1  baseline: 1
# 2267: real 1  pred 0  baseline: 0  WRONG
# 2268: real 0  pred 0  baseline: 0
# 2269: real 1  pred 1  baseline: 1
# 2270: real 0  pred 0  baseline: 0
# 2271: real 1  pred 0  baseline: 0  WRONG
# 2272: real 0  pred 1  baseline: 1  WRONG
# 2273: real 0  pred 0  baseline: 0
# 2274: real 1  pred 1  baseline: 0
# 2275: real 1  pred 1  baseline: 1
# 2276: real 0  pred 0  baseline: 0
# 2277: real 1  pred 1  baseline: 1
# 2278: real 1  pred 1  baseline: 1
# 2279: real 1  pred 0  baseline: 0  WRONG
# 2280: real 0  pred 0  baseline: 0
# 2281: real 0  pred 1  baseline: 1  WRONG
# 2282: real 1  pred 1  baseline: 1
# 2283: real 1  pred 1  baseline: 1
# 2284: real 1  pred 1  baseline: 1
# 2285: real 0  pred 1  baseline: 0  WRONG
# 2286: real 1  pred 1  baseline: 1
# 2287: real 0  pred 1  baseline: 1  WRONG
# 2288: real 1  pred 1  baseline: 1
# 2289: real 1  pred 1  baseline: 1
# 2290: real 0  pred 1  baseline: 1  WRONG
# 2291: real 1  pred 1  baseline: 1
# 2292: real 0  pred 1  baseline: 1  WRONG
# 2293: real 1  pred 0  baseline: 0  WRONG
# 2294: real 1  pred 0  baseline: 0  WRONG
# 2295: real 0  pred 0  baseline: 0
# 2296: real 1  pred 1  baseline: 0
# 2297: real 1  pred 0  baseline: 0  WRONG
# 2298: real 0  pred 1  baseline: 1  WRONG
# 2299: real 0  pred 1  baseline: 1  WRONG
# 2300: real 1  pred 0  baseline: 0  WRONG
# 2301: real 0  pred 0  baseline: 0
# 2302: real 1  pred 1  baseline: 1
# 2303: real 0  pred 0  baseline: 0
# 2304: real 0  pred 0  baseline: 0
# 2305: real 1  pred 0  baseline: 0  WRONG
# 2306: real 0  pred 0  baseline: 0
# 2307: real 1  pred 0  baseline: 0  WRONG
# 2308: real 1  pred 1  baseline: 1
# 2309: real 0  pred 0  baseline: 0
# 2310: real 1  pred 1  baseline: 1
# 2311: real 0  pred 1  baseline: 0  WRONG
# 2312: real 0  pred 0  baseline: 0
# 2313: real 1  pred 1  baseline: 0
# 2314: real 0  pred 1  baseline: 1  WRONG
# 2315: real 1  pred 1  baseline: 1
# 2316: real 1  pred 1  baseline: 1
# 2317: real 1  pred 1  baseline: 1
# 2318: real 1  pred 1  baseline: 1
# 2319: real 0  pred 0  baseline: 0
# 2320: real 1  pred 1  baseline: 0
# 2321: real 1  pred 1  baseline: 1
# 2322: real 1  pred 0  baseline: 0  WRONG
# 2323: real 1  pred 1  baseline: 1
# 2324: real 0  pred 0  baseline: 0
# 2325: real 1  pred 1  baseline: 1
# 2326: real 1  pred 1  baseline: 1
# 2327: real 1  pred 1  baseline: 0
# 2328: real 0  pred 0  baseline: 0
# 2329: real 0  pred 1  baseline: 0  WRONG
# 2330: real 0  pred 0  baseline: 0
# 2331: real 1  pred 0  baseline: 0  WRONG
# 2332: real 1  pred 1  baseline: 1
# 2333: real 1  pred 1  baseline: 1
# 2334: real 1  pred 1  baseline: 1
# 2335: real 0  pred 0  baseline: 0
# 2336: real 0  pred 0  baseline: 0
# 2337: real 1  pred 1  baseline: 1
# 2338: real 1  pred 1  baseline: 1
# 2339: real 0  pred 0  baseline: 0
# 2340: real 1  pred 1  baseline: 1
# 2341: real 1  pred 1  baseline: 1
# 2342: real 1  pred 1  baseline: 1
# 2343: real 0  pred 0  baseline: 0
# 2344: real 0  pred 1  baseline: 1  WRONG
# 2345: real 1  pred 1  baseline: 1
# 2346: real 1  pred 1  baseline: 1
# 2347: real 0  pred 1  baseline: 0  WRONG
# 2348: real 0  pred 0  baseline: 0
# 2349: real 1  pred 0  baseline: 0  WRONG
# 2350: real 0  pred 1  baseline: 0  WRONG
# 2351: real 1  pred 1  baseline: 1
# 2352: real 0  pred 1  baseline: 1  WRONG
# 2353: real 1  pred 0  baseline: 0  WRONG
# 2354: real 0  pred 1  baseline: 0  WRONG
# 2355: real 1  pred 0  baseline: 0  WRONG
# 2356: real 0  pred 0  baseline: 0
# 2357: real 0  pred 0  baseline: 0
# 2358: real 1  pred 1  baseline: 1
# 2359: real 1  pred 1  baseline: 1
# 2360: real 1  pred 1  baseline: 1
# 2361: real 1  pred 1  baseline: 1
# 2362: real 1  pred 0  baseline: 0  WRONG
# 2363: real 1  pred 1  baseline: 1
# 2364: real 0  pred 1  baseline: 0  WRONG
# 2365: real 0  pred 0  baseline: 0
# 2366: real 1  pred 0  baseline: 0  WRONG
# 2367: real 1  pred 1  baseline: 1
# 2368: real 0  pred 0  baseline: 0
# 2369: real 0  pred 1  baseline: 1  WRONG
# 2370: real 0  pred 0  baseline: 0
# 2371: real 0  pred 0  baseline: 0
# 2372: real 1  pred 1  baseline: 1
# 2373: real 1  pred 1  baseline: 1
# 2374: real 1  pred 1  baseline: 1
# 2375: real 1  pred 1  baseline: 1
# 2376: real 1  pred 1  baseline: 1
# 2377: real 1  pred 0  baseline: 1  WRONG
# 2378: real 1  pred 1  baseline: 1
# 2379: real 1  pred 1  baseline: 1
# 2380: real 1  pred 1  baseline: 0
# 2381: real 1  pred 0  baseline: 0  WRONG
# 2382: real 0  pred 0  baseline: 0
# 2383: real 1  pred 1  baseline: 1
# 2384: real 1  pred 1  baseline: 1
# 2385: real 0  pred 1  baseline: 1  WRONG
# 2386: real 1  pred 0  baseline: 0  WRONG
# 2387: real 1  pred 0  baseline: 0  WRONG
# 2388: real 1  pred 0  baseline: 0  WRONG
# 2389: real 0  pred 0  baseline: 0
# 2390: real 1  pred 1  baseline: 1
# 2391: real 1  pred 1  baseline: 1
# 2392: real 0  pred 0  baseline: 0
# 2393: real 1  pred 1  baseline: 1
# 2394: real 0  pred 0  baseline: 1
# 2395: real 0  pred 0  baseline: 0
# 2396: real 1  pred 1  baseline: 1
# 2397: real 0  pred 1  baseline: 0  WRONG
# 2398: real 1  pred 1  baseline: 1
# 2399: real 1  pred 1  baseline: 1
# 2400: real 1  pred 1  baseline: 0
# 2401: real 1  pred 1  baseline: 1
# 2402: real 1  pred 0  baseline: 0  WRONG
# 2403: real 0  pred 0  baseline: 0
# 2404: real 1  pred 1  baseline: 1
# 2405: real 1  pred 1  baseline: 1
# 2406: real 0  pred 1  baseline: 0  WRONG
# 2407: real 0  pred 0  baseline: 1
# 2408: real 1  pred 1  baseline: 1
# 2409: real 1  pred 0  baseline: 0  WRONG
# 2410: real 1  pred 1  baseline: 1
# 2411: real 0  pred 1  baseline: 1  WRONG
# 2412: real 1  pred 1  baseline: 1
# 2413: real 1  pred 1  baseline: 0
# 2414: real 1  pred 1  baseline: 1
# 2415: real 0  pred 0  baseline: 0
# 2416: real 1  pred 0  baseline: 1  WRONG
# 2417: real 0  pred 0  baseline: 0
# 2418: real 1  pred 1  baseline: 1
# 2419: real 1  pred 1  baseline: 0
# 2420: real 0  pred 0  baseline: 0
# 2421: real 0  pred 0  baseline: 0
# 2422: real 1  pred 0  baseline: 1  WRONG
# 2423: real 1  pred 1  baseline: 1
# 2424: real 0  pred 1  baseline: 0  WRONG
# 2425: real 1  pred 1  baseline: 1
# 2426: real 1  pred 1  baseline: 1
# 2427: real 1  pred 0  baseline: 0  WRONG
# 2428: real 0  pred 1  baseline: 1  WRONG
# 2429: real 1  pred 1  baseline: 1
# 2430: real 0  pred 0  baseline: 0
# 2431: real 1  pred 1  baseline: 1
# 2432: real 0  pred 0  baseline: 0
# 2433: real 1  pred 0  baseline: 0  WRONG
# 2434: real 1  pred 1  baseline: 1
# 2435: real 1  pred 1  baseline: 1
# 2436: real 1  pred 1  baseline: 1
# 2437: real 0  pred 1  baseline: 0  WRONG
# 2438: real 1  pred 1  baseline: 1
# 2439: real 1  pred 0  baseline: 0  WRONG
# 2440: real 0  pred 1  baseline: 0  WRONG
# 2441: real 1  pred 0  baseline: 0  WRONG
# 2442: real 1  pred 1  baseline: 1
# 2443: real 0  pred 0  baseline: 0
# 2444: real 0  pred 1  baseline: 1  WRONG
# 2445: real 1  pred 1  baseline: 1
# 2446: real 1  pred 1  baseline: 1
# 2447: real 0  pred 1  baseline: 1  WRONG
# 2448: real 0  pred 1  baseline: 1  WRONG
# 2449: real 1  pred 1  baseline: 1
# 2450: real 1  pred 1  baseline: 1
# 2451: real 1  pred 1  baseline: 1
# 2452: real 1  pred 1  baseline: 1
# 2453: real 1  pred 1  baseline: 1
# 2454: real 1  pred 1  baseline: 1
# 2455: real 1  pred 1  baseline: 1
# 2456: real 1  pred 1  baseline: 0
# 2457: real 1  pred 1  baseline: 1
# 2458: real 1  pred 1  baseline: 1
# 2459: real 0  pred 0  baseline: 0
# 2460: real 1  pred 0  baseline: 1  WRONG
# 2461: real 1  pred 1  baseline: 0
# 2462: real 0  pred 0  baseline: 0
# 2463: real 1  pred 1  baseline: 1
# 2464: real 1  pred 1  baseline: 1
# 2465: real 0  pred 1  baseline: 0  WRONG
# 2466: real 1  pred 0  baseline: 0  WRONG
# 2467: real 0  pred 0  baseline: 0
# 2468: real 0  pred 0  baseline: 0
# 2469: real 0  pred 0  baseline: 0
# 2470: real 1  pred 0  baseline: 0  WRONG
# 2471: real 0  pred 1  baseline: 0  WRONG
# 2472: real 1  pred 0  baseline: 0  WRONG
# 2473: real 0  pred 0  baseline: 0
# 2474: real 1  pred 0  baseline: 0  WRONG
# 2475: real 1  pred 1  baseline: 1
# 2476: real 1  pred 1  baseline: 1
# 2477: real 1  pred 1  baseline: 1
# 2478: real 1  pred 1  baseline: 0
# 2479: real 1  pred 1  baseline: 1
# 2480: real 0  pred 0  baseline: 0

# %%
# Probs
y_prob = grid_search_xgb.best_estimator_.predict_proba(X_test_data).tolist()

# %%
from statistics import mean, median

# Get avg diff for probs total, for each incorrect pred
probs_diff_total = []  # all diff
probs_diff_cor = []  # When the model was correct
probs_diff_inc = []  # when the model was incorrect
probs_diff_base = []  # when the baseline was incorect
probs_diff_base_cor_model_inc = []  # when the baseline was correct (ie no upset) but the model predicted an upset
probs_diff_base_inc_model_cor = []  # when the model predicted an upset correctly

score_diff_total = []  # all diff
score_diff_cor = []  # When the model was correct
score_diff_inc = []  # when the model was incorrect
score_diff_base = []  # when the baseline was incorect
score_diff_base_cor_model_inc = []  # when the baseline was correct (ie no upset) but the model predicted an upset
score_diff_base_inc_model_cor = []  # when the model predicted an upset correctly

for t, p, pr, b, (_, row) in zip(y_test.values.flatten(), y_pred, y_prob, baseline_preds, X_test_pre_drop.iterrows()):
    diff = abs(pr[0] - pr[1])
    diff_pts = abs(row['PTS-V'] - row['PTS-H'])
    probs_diff_total.append(diff)
    score_diff_total.append(diff_pts)
    if t != p:
        probs_diff_inc.append(diff)
        score_diff_inc.append(diff_pts)
    if t == p:
        probs_diff_cor.append(diff)
        score_diff_cor.append(diff_pts)
    if b != t:
        probs_diff_base.append(diff)
        score_diff_base.append(diff_pts)
    if b == t and t != p:
        probs_diff_base_cor_model_inc.append(diff)
        score_diff_base_cor_model_inc.append(diff_pts)
    if b != t and t == p:
        probs_diff_base_inc_model_cor.append(diff)
        score_diff_base_inc_model_cor.append(diff_pts)

print('Probs diff avg total: Probs - {:.3f}  {:.3f}   Score -  {:.3f}  {:.3f}'.format(mean(probs_diff_total), median(probs_diff_total), mean(score_diff_total), median(score_diff_total)))
print('Probs diff avg cor: Probs - {:.3f}  {:.3f}   Score -  {:.3f}  {:.3f}'.format(mean(probs_diff_cor), median(probs_diff_cor), mean(score_diff_cor), median(score_diff_cor)))
print('Probs diff avg inc: Probs - {:.3f}  {:.3f}   Score -  {:.3f}  {:.3f}'.format(mean(probs_diff_inc), median(probs_diff_inc), mean(score_diff_inc), median(score_diff_inc)))
print('Probs diff avg base inc: Probs - {:.3f}  {:.3f}   Score -  {:.3f}  {:.3f}'.format(mean(probs_diff_base), median(probs_diff_base), mean(score_diff_base), median(score_diff_base)))
print('Probs diff avg base cor model inc: Probs - {:.3f}  {:.3f}   Score -  {:.3f}  {:.3f}'.format(mean(probs_diff_base_cor_model_inc), median(probs_diff_base_cor_model_inc), mean(score_diff_base_cor_model_inc), median(score_diff_base_cor_model_inc)))
print('Probs diff avg base inc model cor: Probs - {:.3f}  {:.3f}   Score -  {:.3f}  {:.3f}'.format(mean(probs_diff_base_inc_model_cor), median(probs_diff_base_inc_model_cor), mean(score_diff_base_inc_model_cor), median(score_diff_base_inc_model_cor)))
# Out:
# Probs diff avg total: Probs - 0.298  0.275   Score -  11.308  9.000
# Probs diff avg cor: Probs - 0.327  0.316   Score -  12.326  10.000
# Probs diff avg inc: Probs - 0.231  0.196   Score -  8.967  7.000
# Probs diff avg base inc: Probs - 0.235  0.214   Score -  9.936  8.000
# Probs diff avg base cor model inc: Probs - 0.154  0.134   Score -  8.815  8.000
# Probs diff avg base inc model cor: Probs - 0.162  0.139   Score -  12.078  10.000

# %%
# Remove preds that corrospond to prob diff outside of some margin
margin = 0.1
new_preds = []
new_test = []
for t, p, pr in zip(y_test.values.flatten(), y_pred, y_prob):
    if abs(pr[0] - pr[1]) > margin:
        new_preds.append(p)
        new_test.append(t)
print('{:.3f}% of orginal data included'.format(len(new_preds) / len(y_pred)))
accuracy_score(new_preds, new_test)
# Out:
# 0.819% of orginal data included
# 0.723781388478582
